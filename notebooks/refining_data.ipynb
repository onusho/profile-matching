# %%
import pandas as pd
import _pickle as pickle
import numpy as np
from scipy.stats import halfnorm

# %%
with open(".\\data\\profiles.pkl",'rb') as fp:
    df = pickle.load(fp)
df.head()
# Out:
#                                                 Bios  Movies  TV  Religion  \
# 0  Typical twitter fanatic. Infuriatingly humble ...       5   3         4
# 1  Web junkie. Analyst. Infuriatingly humble intr...       7   9         5
# 2  Avid web maven. Food practitioner. Gamer. Twit...       1   2         6
# 3  Twitteraholic. Extreme web fanatic. Food buff....       5   2         7
# 4  Bacon enthusiast. Falls down a lot. Freelance ...       6   6         6
#
#    Music  Sports  Books  Politics
# 0      1       3      6         7
# 1      1       9      4         0
# 2      5       6      5         4
# 3      8       2      6         6
# 4      4       3      6         3

# %%
# Probability dictionary
p = {}

# Movie Genres
movies = ['Adventure',
          'Action',
          'Drama',
          'Comedy',
          'Thriller',
          'Horror',
          'RomCom',
          'Musical',
          'Documentary']

p['Movies'] = [0.28,
               0.21,
               0.16,
               0.14,
               0.09,
               0.06,
               0.04,
               0.01, 
               0.01]

# Religions (could potentially create a spectrum)
religion = ['Catholic',
            'Christian',
            'Jewish',
            'Muslim',
            'Hindu',
            'Buddhist',
            'Spiritual',
            'Other',
            'Agnostic',
            'Atheist']

p['Religion'] = [0.16,
                 0.16,
                 0.01,
                 0.19,
                 0.11,
                 0.05,
                 0.10,
                 0.09,
                 0.07,
                 0.06]

# Music
music = ['Rock',
         'HipHop',
         'Pop',
         'Country',
         'Latin',
         'EDM',
         'Gospel',
         'Jazz',
         'Classical']

p['Music'] = [0.30,
              0.23,
              0.20,
              0.10,
              0.06,
              0.04,
              0.03,
              0.02,
              0.02]

# Sports
sports = ['Football',
          'Baseball',
          'Basketball',
          'Hockey',
          'Soccer',
          'Other']

p['Sports'] = [0.34,
               0.30,
               0.16, 
               0.13,
               0.04,
               0.03]

# Politics (could also put on a spectrum)
politics = ['Liberal',
            'Progressive',
            'Centrist',
            'Moderate',
            'Conservative']

p['Politics'] = [0.26,
                 0.11,
                 0.11,
                 0.15,
                 0.37]

# Social Media
social = ['Facebook',
          'Youtube',
          'Twitter',
          'Reddit',
          'Instagram',
          'Pinterest',
          'LinkedIn',
          'SnapChat',
          'TikTok']

p['Social Media'] = [0.36,
                     0.27,
                     0.11,
                     0.09,
                     0.05,
                     0.03,
                     0.03,
                     0.03,
                     0.03]


age = halfnorm.rvs(loc=18,scale=8, size=df.shape[0]).astype(int)

# %%
categories = [movies, religion, music, politics, social, sports, age]
names = ['Movies','Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age']
combined = dict(zip(names, categories))

# %%
with open(".\\data\\refined_profiles.pkl",'rb') as fp:
    refined_df = pickle.load(fp)
refined_df.head()
# Out:
#                                                 Bios  \
# 0  Typical twitter fanatic. Infuriatingly humble ...
# 1  Web junkie. Analyst. Infuriatingly humble intr...
# 2  Avid web maven. Food practitioner. Gamer. Twit...
# 3  Twitteraholic. Extreme web fanatic. Food buff....
# 4  Bacon enthusiast. Falls down a lot. Freelance ...
#
#                        Movies   Religion                  Music      Politics  \
# 0          [Thriller, Action]   Buddhist    [Gospel, Pop, Rock]   Progressive
# 1             [Comedy, Drama]  Spiritual          [HipHop, Pop]  Conservative
# 2            [Horror, Comedy]  Christian         [HipHop, Rock]      Moderate
# 3         [Adventure, Comedy]   Agnostic                 [Rock]      Moderate
# 4  [Action, Adventure, Drama]      Hindu  [Latin, Rock, HipHop]  Conservative
#
#                    Social Media                          Sports  Age
# 0  [Twitter, Reddit, Instagram]  [Basketball, Football, Hockey]   19
# 1           [Twitter, Facebook]    [Basketball, Soccer, Hockey]   19
# 2             [Reddit, Youtube]            [Baseball, Football]   21
# 3           [Facebook, Youtube]  [Basketball, Football, Hockey]   25
# 4    [Twitter, TikTok, Youtube]  [Hockey, Football, Basketball]   19

# %%
list(df.columns)[1:]
# Out:
# ['Movies', 'Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age']

# %%
list(combined.keys())
# Out:
# ['Movies', 'Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age']

# %%
def get_input(bio='',movies_list='', religion='', music_list='', politics='', social_media_list='', sports_list='', age = 0):
    return (bio, (movies_list, religion, music_list, politics, social_media_list, sports_list, age))
bio, categories = get_input()
len(categories)
# Out:
# 7

# %%
def get_profile():
    bio, categories = get_input()
    profile = pd.DataFrame(columns=df.columns, index=[df.index[-1] + 1])
    profile['Bios'] = bio
    
    for i, name in enumerate(list(combined.keys())):
        profile[name] = categories[i]
    return profile

profile = get_profile()
profile.columns
# Out:
# Index(['Bios', 'Movies', 'Religion', 'Music', 'Politics', 'Social Media',
#        'Sports', 'Age'],
#       dtype='object')

# %%
with open('..\\data\\combined.pkl', 'wb') as f:
    pickle.dump(combined, f)
with open('..\\data\\probability.pkl', 'wb') as f:
    pickle.dump(p, f)

# %%
combined
# Out:
# {'Movies': ['Adventure',
#   'Action',
#   'Drama',
#   'Comedy',
#   'Thriller',
#   'Horror',
#   'RomCom',
#   'Musical',
#   'Documentary'],
#  'Religion': ['Catholic',
#   'Christian',
#   'Jewish',
#   'Muslim',
#   'Hindu',
#   'Buddhist',
#   'Spiritual',
#   'Other',
#   'Agnostic',
#   'Atheist'],
#  'Music': ['Rock',
#   'HipHop',
#   'Pop',
#   'Country',
#   'Latin',
#   'EDM',
#   'Gospel',
#   'Jazz',
#   'Classical'],
#  'Politics': ['Liberal',
#   'Progressive',
#   'Centrist',
#   'Moderate',
#   'Conservative'],
#  'Social Media': ['Facebook',
#   'Youtube',
#   'Twitter',
#   'Reddit',
#   'Instagram',
#   'Pinterest',
#   'LinkedIn',
#   'SnapChat',
#   'TikTok'],
#  'Sports': ['Football', 'Baseball', 'Basketball', 'Hockey', 'Soccer', 'Other'],
#  'Age': array([24, 26, 19, ..., 28, 20, 18], shape=(6600,))}

# %%
# religion, politics have only one value
# age is decided from half normal distribution
# rest can have max 3 choices
for name, category in combined.items():
    if name in ['Religion', 'Politics']:
        df[name] = np.random.choice(category, df.shape[0], p=p[name])  
    elif name == 'Age':
        df[name] = category
    else:
        try:
            # randomly choose strings from category, with size df rows, 1, 3, and probability p
            df[name] = list(np.random.choice(category, size=(df.shape[0],1,3), p=p[name]))
        except:
            df[name] = list(np.random.choice(category, size=(df.shape[0],1,3)))
        
        df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# Out:
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(category, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = np.random.choice(category, df.shape[0], p=p[name])
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(category, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = np.random.choice(category, df.shape[0], p=p[name])
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(category, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(category, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\Anush\AppData\Local\Temp\ipykernel_12684\980672064.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical twitter fanatic. Infuriatingly humble ...
# 1     Web junkie. Analyst. Infuriatingly humble intr...
# 2     Avid web maven. Food practitioner. Gamer. Twit...
# 3     Twitteraholic. Extreme web fanatic. Food buff....
# 4     Bacon enthusiast. Falls down a lot. Freelance ...
# ...                                                 ...
# 6595  Typical pop culture nerd. Infuriatingly humble...
# 6596  Avid web junkie. Lifelong alcohol guru. Hardco...
# 6597  Music ninja. Bacon fanatic. Reader. Total comm...
# 6598  Communicator. Bacon lover. Award-winning intro...
# 6599  Unapologetic tv aficionado. Devoted twitter en...
#
#                              Movies   Religion                        Music  \
# 0        [Drama, Adventure, Action]      Other                   [Pop, EDM]
# 1             [Adventure, Thriller]      Hindu                  [Pop, Rock]
# 2        [Drama, Adventure, Action]     Muslim              [Country, Rock]
# 3               [Adventure, Action]   Catholic            [Country, HipHop]
# 4       [Adventure, Action, Comedy]      Hindu                  [Pop, Rock]
# ...                             ...        ...                          ...
# 6595             [Drama, Adventure]   Catholic     [HipHop, Pop, Classical]
# 6596    [Drama, Adventure, Musical]  Spiritual      [Country, HipHop, Rock]
# 6597        [Drama, Action, Comedy]    Atheist               [Country, Pop]
# 6598               [Horror, Comedy]      Other                     [HipHop]
# 6599  [Thriller, Adventure, Action]      Hindu  [Latin, Classical, Country]
#
#           Politics                      Social Media  \
# 0      Progressive  [Pinterest, Facebook, Instagram]
# 1      Progressive                        [Facebook]
# 2     Conservative      [Twitter, Youtube, Facebook]
# 3         Moderate                [Twitter, Youtube]
# 4     Conservative               [Youtube, Facebook]
# ...            ...                               ...
# 6595       Liberal               [Youtube, Facebook]
# 6596  Conservative               [Youtube, SnapChat]
# 6597  Conservative        [Reddit, Facebook, TikTok]
# 6598  Conservative                        [Facebook]
# 6599      Centrist                [Twitter, Youtube]
#
#                                 Sports  Age
# 0            [Football, Other, Hockey]   23
# 1                           [Baseball]   18
# 2       [Basketball, Baseball, Hockey]   29
# 3     [Football, Baseball, Basketball]   25
# 4         [Football, Baseball, Hockey]   19
# ...                                ...  ...
# 6595  [Football, Baseball, Basketball]   24
# 6596              [Basketball, Hockey]   28
# 6597                        [Football]   19
# 6598    [Football, Soccer, Basketball]   18
# 6599      [Football, Baseball, Soccer]   25
#
# [6600 rows x 8 columns]

# %%
df['Religion'] = pd.Categorical(df.Religion, ordered=True,
                                categories=['Catholic',
                                            'Christian',
                                            'Jewish',
                                            'Muslim',
                                            'Hindu',
                                            'Buddhist',
                                            'Spiritual',
                                            'Other',
                                            'Agnostic',
                                            'Atheist'])

df['Politics'] = pd.Categorical(df.Politics, ordered=True,
                                categories=['Liberal',
                                            'Progressive',
                                            'Centrist',
                                            'Moderate',
                                            'Conservative'])

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical twitter fanatic. Infuriatingly humble ...
# 1     Web junkie. Analyst. Infuriatingly humble intr...
# 2     Avid web maven. Food practitioner. Gamer. Twit...
# 3     Twitteraholic. Extreme web fanatic. Food buff....
# 4     Bacon enthusiast. Falls down a lot. Freelance ...
# ...                                                 ...
# 6595  Typical pop culture nerd. Infuriatingly humble...
# 6596  Avid web junkie. Lifelong alcohol guru. Hardco...
# 6597  Music ninja. Bacon fanatic. Reader. Total comm...
# 6598  Communicator. Bacon lover. Award-winning intro...
# 6599  Unapologetic tv aficionado. Devoted twitter en...
#
#                              Movies   Religion                        Music  \
# 0        [Drama, Adventure, Action]      Other                   [Pop, EDM]
# 1             [Adventure, Thriller]      Hindu                  [Pop, Rock]
# 2        [Drama, Adventure, Action]     Muslim              [Country, Rock]
# 3               [Adventure, Action]   Catholic            [Country, HipHop]
# 4       [Adventure, Action, Comedy]      Hindu                  [Pop, Rock]
# ...                             ...        ...                          ...
# 6595             [Drama, Adventure]   Catholic     [HipHop, Pop, Classical]
# 6596    [Drama, Adventure, Musical]  Spiritual      [Country, HipHop, Rock]
# 6597        [Drama, Action, Comedy]    Atheist               [Country, Pop]
# 6598               [Horror, Comedy]      Other                     [HipHop]
# 6599  [Thriller, Adventure, Action]      Hindu  [Latin, Classical, Country]
#
#           Politics                      Social Media  \
# 0      Progressive  [Pinterest, Facebook, Instagram]
# 1      Progressive                        [Facebook]
# 2     Conservative      [Twitter, Youtube, Facebook]
# 3         Moderate                [Twitter, Youtube]
# 4     Conservative               [Youtube, Facebook]
# ...            ...                               ...
# 6595       Liberal               [Youtube, Facebook]
# 6596  Conservative               [Youtube, SnapChat]
# 6597  Conservative        [Reddit, Facebook, TikTok]
# 6598  Conservative                        [Facebook]
# 6599      Centrist                [Twitter, Youtube]
#
#                                 Sports  Age
# 0            [Football, Other, Hockey]   23
# 1                           [Baseball]   18
# 2       [Basketball, Baseball, Hockey]   29
# 3     [Football, Baseball, Basketball]   25
# 4         [Football, Baseball, Hockey]   19
# ...                                ...  ...
# 6595  [Football, Baseball, Basketball]   24
# 6596              [Basketball, Hockey]   28
# 6597                        [Football]   19
# 6598    [Football, Soccer, Basketball]   18
# 6599      [Football, Baseball, Soccer]   25
#
# [6600 rows x 8 columns]

# %%
with open("refined_profiles.pkl",'wb') as fp:
    pickle.dump(df, fp)

# %%
with open("refined_profiles.pkl",'rb') as fp:
    df = pickle.load(fp)
df
# Out:
#                                                    Bios  \
# 0     Typical twitter fanatic. Infuriatingly humble ...
# 1     Web junkie. Analyst. Infuriatingly humble intr...
# 2     Avid web maven. Food practitioner. Gamer. Twit...
# 3     Twitteraholic. Extreme web fanatic. Food buff....
# 4     Bacon enthusiast. Falls down a lot. Freelance ...
# ...                                                 ...
# 6595  Typical pop culture nerd. Infuriatingly humble...
# 6596  Avid web junkie. Lifelong alcohol guru. Hardco...
# 6597  Music ninja. Bacon fanatic. Reader. Total comm...
# 6598  Communicator. Bacon lover. Award-winning intro...
# 6599  Unapologetic tv aficionado. Devoted twitter en...
#
#                              Movies   Religion                        Music  \
# 0        [Drama, Adventure, Action]      Other                   [Pop, EDM]
# 1             [Adventure, Thriller]      Hindu                  [Pop, Rock]
# 2        [Drama, Adventure, Action]     Muslim              [Country, Rock]
# 3               [Adventure, Action]   Catholic            [Country, HipHop]
# 4       [Adventure, Action, Comedy]      Hindu                  [Pop, Rock]
# ...                             ...        ...                          ...
# 6595             [Drama, Adventure]   Catholic     [HipHop, Pop, Classical]
# 6596    [Drama, Adventure, Musical]  Spiritual      [Country, HipHop, Rock]
# 6597        [Drama, Action, Comedy]    Atheist               [Country, Pop]
# 6598               [Horror, Comedy]      Other                     [HipHop]
# 6599  [Thriller, Adventure, Action]      Hindu  [Latin, Classical, Country]
#
#           Politics                      Social Media  \
# 0      Progressive  [Pinterest, Facebook, Instagram]
# 1      Progressive                        [Facebook]
# 2     Conservative      [Twitter, Youtube, Facebook]
# 3         Moderate                [Twitter, Youtube]
# 4     Conservative               [Youtube, Facebook]
# ...            ...                               ...
# 6595       Liberal               [Youtube, Facebook]
# 6596  Conservative               [Youtube, SnapChat]
# 6597  Conservative        [Reddit, Facebook, TikTok]
# 6598  Conservative                        [Facebook]
# 6599      Centrist                [Twitter, Youtube]
#
#                                 Sports  Age
# 0            [Football, Other, Hockey]   23
# 1                           [Baseball]   18
# 2       [Basketball, Baseball, Hockey]   29
# 3     [Football, Baseball, Basketball]   25
# 4         [Football, Baseball, Hockey]   19
# ...                                ...  ...
# 6595  [Football, Baseball, Basketball]   24
# 6596              [Basketball, Hockey]   28
# 6597                        [Football]   19
# 6598    [Football, Soccer, Basketball]   18
# 6599      [Football, Baseball, Soccer]   25
#
# [6600 rows x 8 columns]

# %%
df.to_csv("refined_profiles.csv", index=False)

# %%
df = pd.read_csv('refined_profiles.csv')
df
# Out:
#                                                    Bios  \
# 0     Typical twitter fanatic. Infuriatingly humble ...
# 1     Web junkie. Analyst. Infuriatingly humble intr...
# 2     Avid web maven. Food practitioner. Gamer. Twit...
# 3     Twitteraholic. Extreme web fanatic. Food buff....
# 4     Bacon enthusiast. Falls down a lot. Freelance ...
# ...                                                 ...
# 6595  Typical pop culture nerd. Infuriatingly humble...
# 6596  Avid web junkie. Lifelong alcohol guru. Hardco...
# 6597  Music ninja. Bacon fanatic. Reader. Total comm...
# 6598  Communicator. Bacon lover. Award-winning intro...
# 6599  Unapologetic tv aficionado. Devoted twitter en...
#
#                                    Movies   Religion  \
# 0        ['Drama', 'Adventure', 'Action']      Other
# 1               ['Adventure', 'Thriller']      Hindu
# 2        ['Drama', 'Adventure', 'Action']     Muslim
# 3                 ['Adventure', 'Action']   Catholic
# 4       ['Adventure', 'Action', 'Comedy']      Hindu
# ...                                   ...        ...
# 6595               ['Drama', 'Adventure']   Catholic
# 6596    ['Drama', 'Adventure', 'Musical']  Spiritual
# 6597        ['Drama', 'Action', 'Comedy']    Atheist
# 6598                 ['Horror', 'Comedy']      Other
# 6599  ['Thriller', 'Adventure', 'Action']      Hindu
#
#                                   Music      Politics  \
# 0                        ['Pop', 'EDM']   Progressive
# 1                       ['Pop', 'Rock']   Progressive
# 2                   ['Country', 'Rock']  Conservative
# 3                 ['Country', 'HipHop']      Moderate
# 4                       ['Pop', 'Rock']  Conservative
# ...                                 ...           ...
# 6595     ['HipHop', 'Pop', 'Classical']       Liberal
# 6596      ['Country', 'HipHop', 'Rock']  Conservative
# 6597                 ['Country', 'Pop']  Conservative
# 6598                         ['HipHop']  Conservative
# 6599  ['Latin', 'Classical', 'Country']      Centrist
#
#                                 Social Media  \
# 0     ['Pinterest', 'Facebook', 'Instagram']
# 1                               ['Facebook']
# 2         ['Twitter', 'Youtube', 'Facebook']
# 3                     ['Twitter', 'Youtube']
# 4                    ['Youtube', 'Facebook']
# ...                                      ...
# 6595                 ['Youtube', 'Facebook']
# 6596                 ['Youtube', 'SnapChat']
# 6597        ['Reddit', 'Facebook', 'TikTok']
# 6598                            ['Facebook']
# 6599                  ['Twitter', 'Youtube']
#
#                                       Sports  Age
# 0            ['Football', 'Other', 'Hockey']   23
# 1                               ['Baseball']   18
# 2       ['Basketball', 'Baseball', 'Hockey']   29
# 3     ['Football', 'Baseball', 'Basketball']   25
# 4         ['Football', 'Baseball', 'Hockey']   19
# ...                                      ...  ...
# 6595  ['Football', 'Baseball', 'Basketball']   24
# 6596                ['Basketball', 'Hockey']   28
# 6597                            ['Football']   19
# 6598    ['Football', 'Soccer', 'Basketball']   18
# 6599      ['Football', 'Baseball', 'Soccer']   25
#
# [6600 rows x 8 columns]
