# %%
import os
import time
import json
from dotenv import load_dotenv
import pandas as pd
from google import genai

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
# uses exponential backoff when calling gemini api
def generate_text(prompt, model="gemini-2.0-flash-lite-preview-02-05", max_retries=5, initial_wait=2):

    attempt = 0
    wait_time = initial_wait

    while attempt < max_retries:
        try:
            response = client.models.generate_content(
                model=model,
                contents=[prompt]
            )
            return response.text
        except Exception as e:
            print(f"Error encountered: {e}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
            wait_time *= 2  # backoff
            attempt += 1

    raise Exception("Max retries reached. The request could not be completed.")

# def validate_profile(profile):
#     required_keys = ["bio", "movies", "tv", "religion", "music", "sports", "books", "politics"]
    
#     # checking all keys present or not
#     for key in required_keys:
#         if key not in profile:
#             return False
    
#     # checking range of numeric entries
#     for key in ["bio", "movies", "tv", "religion", "music", "sports", "books", "politics"]:
#         value = profile[key]
#         if not isinstance(value, str):
#             return False
        
#     return True

def generate_profiles(n_profiles=500):
    prompt = f"""
You are a profile generator. Create {n_profiles} unique dating profiles.
Return them as a valid JSON array of objects. Each object has these fields, create creative bio but only choose one value from list of options from below:
    "bio": (string) a short creative biography (1-2 sentences),
    "movies": ("Action", "Comedy", "Drama", "Horror", "Science Fiction"),
    "religion": ("Christianity", "Islam", "Hinduism", "Buddhism", "Judaism"),
    "music": ("Rock", "Pop", "Hip-Hop", "Jazz", "Classical"),
    "sports": ("Soccer", "Basketball", "Tennis", "Cricket", "Baseball"),
    "books": ("Fantasy", "Mystery", "Romance", "Science Fiction", "Non-Fiction"),
    "politics": ("Liberalism", "Conservatism", "Socialism", "Libertarianism", "Communism")
Example for one item in the array:
{{
    "bio": "Coffee fanatic. Amateur traveler. Always up for a new adventure!",
    "movies": "Action",
    "religion": "Islam",
    "music": "Rock",
    "sports": "Basketball",
    "books": "Fantasy",
    "politics": "Conservatism" 
}}
"""
    response_text = generate_text(prompt).replace('json', '').replace("```", "")
    print(response_text)
    try:
        # converting JSON string into list of dictionaries
        raw_profiles = json.loads(response_text)
        print(raw_profiles)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}. Raw Response: {response_text}")
        return []
    
    # valid_profiles = []
    # for p in raw_profiles:
    #     if validate_profile(p):
    #         valid_profiles.append(p)

    # print(f"Generated {len(valid_profiles)} valid profiles out of requested {n_profiles}.")
    return raw_profiles

if __name__ == "__main__":
    total_needed = 10
    batch_size = 10

    all_profiles = []
    total_collected = 0
 
    while total_collected <= total_needed:
        needed_now = min(batch_size, total_needed - total_collected)
        batch = generate_profiles(batch_size)
        all_profiles.extend(batch)
        total_collected = len(all_profiles)
        time.sleep(2)
    
    print(all_profiles)
    df = pd.DataFrame(all_profiles)
    df.rename(
        columns={
            "bio": "Bios",
            "movies": "Movies",
            "tv": "TV",
            "religion": "Religion",
            "music": "Music",
            "sports": "Sports",
            "books": "Books",
            "politics": "Politics"
        },
        inplace=True
    )
    
    print(df.head(10))  
    print(f"\nTotal valid profiles generated: {len(df)}")
    
    df.to_csv("dating_profiles.csv", index=False)
    print("\nSaved to 'dating_profiles.csv'.")
# Out:
# [
#   {
#     "bio": "Avid stargazer with a penchant for philosophical debates. Seeking someone to share sunsets and meaningful conversations.",
#     "movies": "Science Fiction",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Lover of spontaneous road trips and the perfect slice of pizza. Life's too short for boring dates!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Bookworm and history buff searching for my own fairytale ending. Let's explore museums and old bookstores together.",
#     "movies": "Drama",
#     "religion": "Judaism",
#     "music": "Classical",
#     "sports": "Soccer",
#     "books": "Fantasy",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "World traveler with a taste for spicy food and adrenaline rushes. Ready to experience the best life has to offer.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Science Fiction",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Always up for a good laugh and a competitive game night. Looking for my partner in crime.",
#     "movies": "Comedy",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Passionate about art, music, and making a difference. Let's create memories, and change the world.",
#     "movies": "Drama",
#     "religion": "Christianity",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Horror movie enthusiast who enjoys long walks on the beach. Beware of dad jokes.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Classical",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Tech geek, into gaming, and fascinated by the future. Ready to explore new dimensions.",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Science Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Foodie with a deep appreciation for all things delicious, from street tacos to sushi. My love language is food.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Hip-Hop",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Music lover, and concert fanatic, with a soft spot for animals. Always down to try new adventures.",
#     "movies": "Comedy",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   }
# ]
#
# [{'bio': 'Avid stargazer with a penchant for philosophical debates. Seeking someone to share sunsets and meaningful conversations.', 'movies': 'Science Fiction', 'religion': 'Buddhism', 'music': 'Jazz', 'sports': 'Tennis', 'books': 'Non-Fiction', 'politics': 'Liberalism'}, {'bio': "Lover of spontaneous road trips and the perfect slice of pizza. Life's too short for boring dates!", 'movies': 'Comedy', 'religion': 'Christianity', 'music': 'Pop', 'sports': 'Baseball', 'books': 'Romance', 'politics': 'Conservatism'}, {'bio': "Bookworm and history buff searching for my own fairytale ending. Let's explore museums and old bookstores together.", 'movies': 'Drama', 'religion': 'Judaism', 'music': 'Classical', 'sports': 'Soccer', 'books': 'Fantasy', 'politics': 'Socialism'}, {'bio': 'World traveler with a taste for spicy food and adrenaline rushes. Ready to experience the best life has to offer.', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Basketball', 'books': 'Science Fiction', 'politics': 'Libertarianism'}, {'bio': 'Always up for a good laugh and a competitive game night. Looking for my partner in crime.', 'movies': 'Comedy', 'religion': 'Hinduism', 'music': 'Rock', 'sports': 'Cricket', 'books': 'Mystery', 'politics': 'Communism'}, {'bio': "Passionate about art, music, and making a difference. Let's create memories, and change the world.", 'movies': 'Drama', 'religion': 'Christianity', 'music': 'Jazz', 'sports': 'Tennis', 'books': 'Non-Fiction', 'politics': 'Liberalism'}, {'bio': 'Horror movie enthusiast who enjoys long walks on the beach. Beware of dad jokes.', 'movies': 'Horror', 'religion': 'Buddhism', 'music': 'Classical', 'sports': 'Baseball', 'books': 'Romance', 'politics': 'Conservatism'}, {'bio': 'Tech geek, into gaming, and fascinated by the future. Ready to explore new dimensions.', 'movies': 'Science Fiction', 'religion': 'Judaism', 'music': 'Pop', 'sports': 'Soccer', 'books': 'Science Fiction', 'politics': 'Socialism'}, {'bio': 'Foodie with a deep appreciation for all things delicious, from street tacos to sushi. My love language is food.', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Cricket', 'books': 'Mystery', 'politics': 'Libertarianism'}, {'bio': 'Music lover, and concert fanatic, with a soft spot for animals. Always down to try new adventures.', 'movies': 'Comedy', 'religion': 'Hinduism', 'music': 'Rock', 'sports': 'Basketball', 'books': 'Fantasy', 'politics': 'Communism'}]
#
# [
#   {
#     "bio": "I'm a hopeless romantic with a love for a good laugh. Seeking someone to share life's simple joys with!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Tennis",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Avid reader and admirer of the cosmos. I'm looking for a fellow explorer to delve into the unknown.",
#     "movies": "Science Fiction",
#     "religion": "Buddhism",
#     "music": "Classical",
#     "sports": "Cricket",
#     "books": "Science Fiction",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Always up for a thrilling experience and a thought-provoking conversation. Let's unravel some mysteries together!",
#     "movies": "Horror",
#     "religion": "Judaism",
#     "music": "Jazz",
#     "sports": "Baseball",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Passionate about the art of storytelling. I'm searching for someone who appreciates the power of words.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Born to move and groove. Ready to find someone to dance through life with!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "I'm a wanderer with a thirst for knowledge. Interested in connecting with someone who shares a curious spirit.",
#     "movies": "Science Fiction",
#     "religion": "Christianity",
#     "music": "Rock",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Seeking someone who appreciates a good debate and enjoys a strong cup of coffee. Let's challenge each other!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Cricket",
#     "books": "Non-Fiction",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "I believe in living life to the fullest. Ready to find someone to make everyday an adventure!",
#     "movies": "Comedy",
#     "religion": "Judaism",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "I’m a fan of a good plot twist and a captivating story. Seeking someone with a taste for intrigue.",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Soccer",
#     "books": "Mystery",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready to start the next chapter and find my forever person. Always down for a spontaneous outing.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   }
# ]
#
# [{'bio': "I'm a hopeless romantic with a love for a good laugh. Seeking someone to share life's simple joys with!", 'movies': 'Comedy', 'religion': 'Christianity', 'music': 'Pop', 'sports': 'Tennis', 'books': 'Romance', 'politics': 'Liberalism'}, {'bio': "Avid reader and admirer of the cosmos. I'm looking for a fellow explorer to delve into the unknown.", 'movies': 'Science Fiction', 'religion': 'Buddhism', 'music': 'Classical', 'sports': 'Cricket', 'books': 'Science Fiction', 'politics': 'Libertarianism'}, {'bio': "Always up for a thrilling experience and a thought-provoking conversation. Let's unravel some mysteries together!", 'movies': 'Horror', 'religion': 'Judaism', 'music': 'Jazz', 'sports': 'Baseball', 'books': 'Mystery', 'politics': 'Conservatism'}, {'bio': "Passionate about the art of storytelling. I'm searching for someone who appreciates the power of words.", 'movies': 'Drama', 'religion': 'Hinduism', 'music': 'Classical', 'sports': 'Soccer', 'books': 'Non-Fiction', 'politics': 'Socialism'}, {'bio': 'Born to move and groove. Ready to find someone to dance through life with!', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Basketball', 'books': 'Fantasy', 'politics': 'Communism'}, {'bio': "I'm a wanderer with a thirst for knowledge. Interested in connecting with someone who shares a curious spirit.", 'movies': 'Science Fiction', 'religion': 'Christianity', 'music': 'Rock', 'sports': 'Tennis', 'books': 'Science Fiction', 'politics': 'Liberalism'}, {'bio': "Seeking someone who appreciates a good debate and enjoys a strong cup of coffee. Let's challenge each other!", 'movies': 'Drama', 'religion': 'Buddhism', 'music': 'Jazz', 'sports': 'Cricket', 'books': 'Non-Fiction', 'politics': 'Conservatism'}, {'bio': 'I believe in living life to the fullest. Ready to find someone to make everyday an adventure!', 'movies': 'Comedy', 'religion': 'Judaism', 'music': 'Pop', 'sports': 'Baseball', 'books': 'Romance', 'politics': 'Libertarianism'}, {'bio': 'I’m a fan of a good plot twist and a captivating story. Seeking someone with a taste for intrigue.', 'movies': 'Horror', 'religion': 'Hinduism', 'music': 'Classical', 'sports': 'Soccer', 'books': 'Mystery', 'politics': 'Socialism'}, {'bio': 'Ready to start the next chapter and find my forever person. Always down for a spontaneous outing.', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Basketball', 'books': 'Fantasy', 'politics': 'Communism'}]
# [{'bio': 'Avid stargazer with a penchant for philosophical debates. Seeking someone to share sunsets and meaningful conversations.', 'movies': 'Science Fiction', 'religion': 'Buddhism', 'music': 'Jazz', 'sports': 'Tennis', 'books': 'Non-Fiction', 'politics': 'Liberalism'}, {'bio': "Lover of spontaneous road trips and the perfect slice of pizza. Life's too short for boring dates!", 'movies': 'Comedy', 'religion': 'Christianity', 'music': 'Pop', 'sports': 'Baseball', 'books': 'Romance', 'politics': 'Conservatism'}, {'bio': "Bookworm and history buff searching for my own fairytale ending. Let's explore museums and old bookstores together.", 'movies': 'Drama', 'religion': 'Judaism', 'music': 'Classical', 'sports': 'Soccer', 'books': 'Fantasy', 'politics': 'Socialism'}, {'bio': 'World traveler with a taste for spicy food and adrenaline rushes. Ready to experience the best life has to offer.', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Basketball', 'books': 'Science Fiction', 'politics': 'Libertarianism'}, {'bio': 'Always up for a good laugh and a competitive game night. Looking for my partner in crime.', 'movies': 'Comedy', 'religion': 'Hinduism', 'music': 'Rock', 'sports': 'Cricket', 'books': 'Mystery', 'politics': 'Communism'}, {'bio': "Passionate about art, music, and making a difference. Let's create memories, and change the world.", 'movies': 'Drama', 'religion': 'Christianity', 'music': 'Jazz', 'sports': 'Tennis', 'books': 'Non-Fiction', 'politics': 'Liberalism'}, {'bio': 'Horror movie enthusiast who enjoys long walks on the beach. Beware of dad jokes.', 'movies': 'Horror', 'religion': 'Buddhism', 'music': 'Classical', 'sports': 'Baseball', 'books': 'Romance', 'politics': 'Conservatism'}, {'bio': 'Tech geek, into gaming, and fascinated by the future. Ready to explore new dimensions.', 'movies': 'Science Fiction', 'religion': 'Judaism', 'music': 'Pop', 'sports': 'Soccer', 'books': 'Science Fiction', 'politics': 'Socialism'}, {'bio': 'Foodie with a deep appreciation for all things delicious, from street tacos to sushi. My love language is food.', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Cricket', 'books': 'Mystery', 'politics': 'Libertarianism'}, {'bio': 'Music lover, and concert fanatic, with a soft spot for animals. Always down to try new adventures.', 'movies': 'Comedy', 'religion': 'Hinduism', 'music': 'Rock', 'sports': 'Basketball', 'books': 'Fantasy', 'politics': 'Communism'}, {'bio': "I'm a hopeless romantic with a love for a good laugh. Seeking someone to share life's simple joys with!", 'movies': 'Comedy', 'religion': 'Christianity', 'music': 'Pop', 'sports': 'Tennis', 'books': 'Romance', 'politics': 'Liberalism'}, {'bio': "Avid reader and admirer of the cosmos. I'm looking for a fellow explorer to delve into the unknown.", 'movies': 'Science Fiction', 'religion': 'Buddhism', 'music': 'Classical', 'sports': 'Cricket', 'books': 'Science Fiction', 'politics': 'Libertarianism'}, {'bio': "Always up for a thrilling experience and a thought-provoking conversation. Let's unravel some mysteries together!", 'movies': 'Horror', 'religion': 'Judaism', 'music': 'Jazz', 'sports': 'Baseball', 'books': 'Mystery', 'politics': 'Conservatism'}, {'bio': "Passionate about the art of storytelling. I'm searching for someone who appreciates the power of words.", 'movies': 'Drama', 'religion': 'Hinduism', 'music': 'Classical', 'sports': 'Soccer', 'books': 'Non-Fiction', 'politics': 'Socialism'}, {'bio': 'Born to move and groove. Ready to find someone to dance through life with!', 'movies': 'Action', 'religion': 'Islam', 'music': 'Hip-Hop', 'sports': 'Basketball', 'books': 'Fantasy', 'politics': 'Communism'}, {'bio': "I'm a wanderer with a thirst for knowledge. Interested in connecting with someone who shares a curious spirit.", 'movies': 'Science Fiction', 'religion': 'Christianity', 'music': 'Rock', 'sports': 'Tennis', 'books': 'Science Fiction', 'politics': 'Liberalism'}, {'bio': " ...
#                                                 Bios           Movies  \
# 0  Avid stargazer with a penchant for philosophic...  Science Fiction
# 1  Lover of spontaneous road trips and the perfec...           Comedy
# 2  Bookworm and history buff searching for my own...            Drama
# 3  World traveler with a taste for spicy food and...           Action
# 4  Always up for a good laugh and a competitive g...           Comedy
# 5  Passionate about art, music, and making a diff...            Drama
# 6  Horror movie enthusiast who enjoys long walks ...           Horror
# 7  Tech geek, into gaming, and fascinated by the ...  Science Fiction
# 8  Foodie with a deep appreciation for all things...           Action
# 9  Music lover, and concert fanatic, with a soft ...           Comedy
#
#        Religion      Music      Sports            Books        Politics
# 0      Buddhism       Jazz      Tennis      Non-Fiction      Liberalism
# 1  Christianity        Pop    Baseball          Romance    Conservatism
# 2       Judaism  Classical      Soccer          Fantasy       Socialism
# 3         Islam    Hip-Hop  Basketball  Science Fiction  Libertarianism
# 4      Hinduism       Rock     Cricket          Mystery       Communism
# 5  Christianity       Jazz      Tennis      Non-Fiction      Liberalism
# 6      Buddhism  Classical    Baseball          Romance    Conservatism
# 7       Judaism        Pop      Soccer  Science Fiction       Socialism
# 8         Islam    Hip-Hop     Cricket          Mystery  Libertarianism
# 9      Hinduism       Rock  Basketball          Fantasy       Communism
#
# Total valid profiles generated: 20
#
# Saved to 'dating_profiles.csv'.

# %%
df = pd.read_csv('dating_profiles.csv')
df.head()
# Out:
#                                                 Bios           Movies  \
# 0  Avid stargazer with a penchant for philosophic...  Science Fiction
# 1  Lover of spontaneous road trips and the perfec...           Comedy
# 2  Bookworm and history buff searching for my own...            Drama
# 3  World traveler with a taste for spicy food and...           Action
# 4  Always up for a good laugh and a competitive g...           Comedy
#
#        Religion      Music      Sports            Books        Politics
# 0      Buddhism       Jazz      Tennis      Non-Fiction      Liberalism
# 1  Christianity        Pop    Baseball          Romance    Conservatism
# 2       Judaism  Classical      Soccer          Fantasy       Socialism
# 3         Islam    Hip-Hop  Basketball  Science Fiction  Libertarianism
# 4      Hinduism       Rock     Cricket          Mystery       Communism
