# %%
import os
import time
import json
from dotenv import load_dotenv
import pandas as pd
from google import genai

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
# uses exponential backoff when calling gemini api
def generate_text(prompt, model="gemini-2.0-flash-lite-preview-02-05", max_retries=5, initial_wait=2):

    attempt = 0
    wait_time = initial_wait

    while attempt < max_retries:
        try:
            response = client.models.generate_content(
                model=model,
                contents=[prompt]
            )
            return response.text
        except Exception as e:
            print(f"Error encountered: {e}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
            wait_time *= 2  # backoff
            attempt += 1

    raise Exception("Max retries reached. The request could not be completed.")

# def validate_profile(profile):
#     required_keys = ["bio", "movies", "tv", "religion", "music", "sports", "books", "politics"]
    
#     # checking all keys present or not
#     for key in required_keys:
#         if key not in profile:
#             return False
    
#     # checking range of numeric entries
#     for key in ["bio", "movies", "tv", "religion", "music", "sports", "books", "politics"]:
#         value = profile[key]
#         if not isinstance(value, str):
#             return False
        
#     return True

def generate_profiles(n_profiles=500):
    prompt = f"""
You are a profile generator. Create {n_profiles} unique dating profiles.
Return them as a valid JSON array of objects. Each object has these fields, create creative bio but only choose one value from list of options from below:
    "bio": (string) a short creative biography (1-2 sentences),
    "movies": ("Action", "Comedy", "Drama", "Horror", "Science Fiction"),
    "religion": ("Christianity", "Islam", "Hinduism", "Buddhism", "Judaism"),
    "music": ("Rock", "Pop", "Hip-Hop", "Jazz", "Classical"),
    "sports": ("Soccer", "Basketball", "Tennis", "Cricket", "Baseball"),
    "books": ("Fantasy", "Mystery", "Romance", "Science Fiction", "Non-Fiction"),
    "politics": ("Liberalism", "Conservatism", "Socialism", "Libertarianism", "Communism")
Example for one item in the array:
{{
    "bio": "Coffee fanatic. Amateur traveler. Always up for a new adventure!",
    "movies": "Action",
    "religion": "Islam",
    "music": "Rock",
    "sports": "Basketball",
    "books": "Fantasy",
    "politics": "Conservatism" 
}}
"""
    response_text = generate_text(prompt).replace('json', '').replace("```", "")
    print(response_text)
    try:
        # converting JSON string into list of dictionaries
        raw_profiles = json.loads(response_text)
        print(raw_profiles)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}. Raw Response: {response_text}")
        return []
    
    # valid_profiles = []
    # for p in raw_profiles:
    #     if validate_profile(p):
    #         valid_profiles.append(p)

    # print(f"Generated {len(valid_profiles)} valid profiles out of requested {n_profiles}.")
    return raw_profiles

if __name__ == "__main__":
    total_needed = 100
    batch_size = 100

    all_profiles = []
    total_collected = 0
 
    while total_collected < total_needed:
        needed_now = min(batch_size, total_needed - total_collected)
        batch = generate_profiles(batch_size)
        all_profiles.extend(batch)
        total_collected = len(all_profiles)
        time.sleep(2)
    
    print(all_profiles)
    df = pd.DataFrame(all_profiles)
    df.rename(
        columns={
            "bio": "Bios",
            "movies": "Movies",
            "tv": "TV",
            "religion": "Religion",
            "music": "Music",
            "sports": "Sports",
            "books": "Books",
            "politics": "Politics"
        },
        inplace=True
    )
    
    print(df.head(10))  
    print(f"\nTotal valid profiles generated: {len(df)}")
    
    df.to_csv("dating_profiles.csv", index=False)
    print("\nSaved to 'dating_profiles.csv'.")
# Out:
# [
#   {
#     "bio": "Dreamer by day, stargazer by night. Let's explore the universe together, one conversation at a time.",
#     "movies": "Science Fiction",
#     "religion": "Buddhism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "
",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "I'm always curious about the universe, and eager to discover new wonders. Seeking a partner in exploration.",
#     "movies": "Science Fiction",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Always laughing, always ready to have a good time. Looking for someone to share the joys of life with.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Ready to connect and make a difference in the world. Hoping to make new memories and create lasting connections.",
#     "movies": "Drama",
#     "religion": "Islam",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready for adventures, and hoping to find a person to build something special with. Let's create lasting memories.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Ready to experience life's thrills and hoping to find someone special. Let's create a life full of adventure.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#     {
#     "bio": "Seeking someone to share a universe of ideas, and the wonders of science. Let's explore the cosmos together!",
#     "movies": "Science Fiction",
#     "religion": "Christianity",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Love a good laugh and easy conversation. Seeking someone who is down to earth and enjoys life's simple pleasures.",
#     "movies": "Comedy",
#     "religion": "Islam",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Passionate about making a difference in the world, and hoping to find someone who shares my vision.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready to embrace adventure and create unforgettable memories. Looking for a partner who is ready to experience new things.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "I love solving a good mystery, and ready to embark on new adventures. Hoping to share the thrill with someone special.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always searching for new worlds and new experiences. Ready to discover the cosmos with someone amazing.",
#     "movies": "Science Fiction",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Ready to share laughter and fun times, always looking for a good time. Hoping to meet someone special.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Passionate about connecting with people and creating something meaningful. Let's build something incredible together.",
#     "movies": "Drama",
#     "religion": "Islam",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Eager for adventures and creating lasting memories. Looking for someone to make life even more extraordinary.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Enjoying the mysteries of life, and ready to discover more. Hoping to meet that special someone to share the adventure.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#     {
#     "bio": "Looking for someone to explore the universe with, one star at a time. Let's make the most of every moment.",
#     "movies": "Science Fiction",
#     "religion": "Christianity",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Always ready to laugh and have fun, looking for a good time. Hoping to share joy and memories.",
#     "movies": "Comedy",
#     "religion": "Islam",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Ready to experience life and to share the ride. I'm hoping to create some incredible memories with the right person.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready to create memories and embark on new adventures. I want to find someone special to share in my enthusiasm.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Love a good mystery and a good story, and always looking for an adventure. Hoping to meet someone amazing.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "
# Error decoding JSON: Unterminated string starting at: line 856 column 17 (char 27612). Raw Response:
# [
#   {
#     "bio": "Dreamer by day, stargazer by night. Let's explore the universe together, one conversation at a time.",
#     "movies": "Science Fiction",
#     "religion": "Buddhism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Making memories, one laugh at a time. Looking for someone to share life's little joys with.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Finding beauty in the chaos. I believe in good food, good company, and great stories.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Living life to the fullest, one adventure at a time. Ready to create some epic stories together.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "A lover of the arts, the outdoors, and everything in between. Seeking a partner in crime for all of life's adventures.",
#     "movies": "Horror",
#     "religion": "Islam",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Seeking someone with a sense of humor and a thirst for adventure. Let's create some unforgettable moments!",
#     "movies": "Science Fiction",
#     "religion": "Buddhism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Life's a journey, not a destination. Open to new experiences and the people who make them special.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Passionate about making a positive impact. I am hoping to find someone who shares my vision for a better world.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Exploring the world and myself. Always open to meeting new people and sharing a good laugh.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Lost in thought, found in music. Let's create a symphony of memories together.",
#     "movies": "Horror",
#     "religion": "Islam",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#     {
#     "bio": "Adventurous soul ready to explore the world. Seeking someone to share unforgettable moments and create lasting memories.",
#     "movies": "Science Fiction",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Laughing through life's ups and downs. Looking for a partner in crime to share the joy and create some adventures.",
#     "movies": "Comedy",
#     "religion": "Islam",
#     "music": "Rock",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Passionate about making a difference and connecting with others. Searching for someone who appreciates the simple things.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Embracing the journey of life, seeking genuine connections and shared experiences. Ready for adventures and good times.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Obsessed with stories and making memories. Seeking someone to write the next chapter of life's adventure with.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "
",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always searching for new worlds and dimensions, hoping to find someone to share this passion with.",
#     "movies": "Science Fiction",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Finding joy in everyday moments, let's laugh, explore and share life's journey.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Passionate about life and meeting new people, and looking for someone to write the next chapter together.",
#     "movies": "Drama",
#     "religion": "Islam",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Always ready for the next big adventure, hoping to create lasting memories with the right person.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Love a good mystery, and always ready to explore something new. Hoping to find that special someone to share life with.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#     {
#     "bio": "Dreaming of distant galaxies and exploring the unknown. Seeking a partner in the cosmos.",
#     "movies": "Science Fiction",
#     "religion": "Christianity",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Always laughing and enjoying life, looking for a partner to share in the good times.",
#     "movies": "Comedy",
#     "religion": "Islam",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Looking to make a difference in the world, and hoping to connect with someone who shares my passion.",
#     "movies": "Drama",
#     "religion": "Hinduism",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready to explore the world and create lasting memories. Seeking someone to make life even more special.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Love a good mystery and exploring the world around us. Ready to embark on the next chapter with someone special.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always searching for new worlds, eager to explore the stars. Seeking a partner to share this journey.",
#     "movies": "Science Fiction",
#     "religion": "Hinduism",
#     "music": "Classical",
#     "sports": "Tennis",
#     "books": "Science Fiction",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Living life with a smile, ready for laughter and sharing joyful experiences. Looking for a partner in fun.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Baseball",
#     "books": "Romance",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "I am passionate about making a difference in the world. Looking for someone to grow together and inspire.",
#     "movies": "Drama",
#     "religion": "Islam",
#     "music": "Jazz",
#     "sports": "Soccer",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready for the next grand adventure, hoping to make some amazing memories and connections.",
#     "movies": "Action",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Enjoying life's mysteries and ready to seek out thrills. Looking for someone to create a story with.",
#     "movies": "Horror",
#     "religion": "Buddhism",
#     "music": "Rock",
# ...
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Life is to enjoy.  Let's enjoy it together!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Let's dig deep and explore.  I am always learning.",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Let's chase the thrill.  Are you ready?",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "What lies ahead?  Let's find out!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Always on the lookout for fun and adventure.  Who's with me?",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always looking for the next funny thing, I love to laugh.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "I want to learn from you.  Tell me about yourself.",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Always love a mystery.  Let's solve the mystery!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Future is now.  Let's build a future together.",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Get ready!  It's time for an adventure!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Let's laugh and smile.  Life's too short not to!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "What's your story?  I want to know!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Ready for a good scare?  Let's do it!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Future-thinking and ready.  Let's go!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Looking for someone to experience the thrill of life with.  Let's do it!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Life is great!  Let's enjoy it together!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Let's talk about the deep things.  I'm listening.",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Want to be scared?  You found the right person!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Ready for the future?  Let's plan it together.",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#    {
#     "bio": "Adventurous soul with a hunger for new experiences. Looking for a travel buddy!",
#     "movies": "Action",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Exploring the beauty in everyday moments and seeking a companion to share them with.",
#     "movies": "Drama",
#     "religion": "Islam",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Intrigued by the unknown and the mysteries that life holds.  Looking for someone to explore them with.",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "A stargazer and dreamer.  Looking for someone to gaze at the stars with.",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Seeking someone who is not afraid to take risks.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Life is fun!  Let's make it more fun!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Let's talk and learn from each other.  Tell me your story!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Let's get spooky!  Ready for a scare?",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Into the future.  Let's go!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Always up for adventure.  Let's go!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always up for a laugh.  Let's laugh and smile!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Let's explore the world and learn from each other.",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Always up for a good mystery. Let's go!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Ready for the future. Let's build something new!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Action-seeker ready to go! Let's go!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always smiling and laughing! Let's go!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Seeking deep conversations. Come with me!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Let's get scared! Who is with me?!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "The future is waiting. Let's go!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Adrenaline junkie looking for adventures. Who's in?",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Ready to laugh? Let's laugh!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Seeking a partner who seeks to learn. Let's go!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Always love a good scare! Let's get scared!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "The future is now! Let's start planning!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Ready for action! Let's go!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always ready to laugh. Come with me!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Seeking a partner who wants to learn. Let's go!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Let's get scared! Time to get spooked!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Planning the future. Let's go!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Adventurer looking for an explorer. Let's go!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Love to laugh! Let's laugh a lot!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Ready to learn! Time to go!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Love a good scare. Let's get scared!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Ready for the future! Come with me!",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Adventure awaits! Let's go!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Always laughing! Let's laugh!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Seeking to learn from you. Let's go!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Let's get spooked! Time for a scare!",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Let's build the future! Are you with me?",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Adventurous and ready to explore!",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Laughter is my favorite medicine. Let's find it!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Interested in deep talks. Let's dig deep!",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Scary movies and dark nights are the best. Wanna come?",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Obsessed with all things futuristic. What do you think?",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#   {
#     "bio": "Ready to live life in fast-forward.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Here for the good times. Let's smile!",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Looking for the next great story.",
#     "movies": "Drama",
#     "religion": "Buddhism",
#     "music": "Jazz",
#     "sports": "Tennis",
#     "books": "Non-Fiction",
#     "politics": "Socialism"
#   },
#   {
#     "bio": "Can't resist a good thriller.",
#     "movies": "Horror",
#     "religion": "Hinduism",
#     "music": "Rock",
#     "sports": "Cricket",
#     "books": "Mystery",
#     "politics": "Libertarianism"
#   },
#   {
#     "bio": "Let's build the future. I'll bring the ideas.",
#     "movies": "Science Fiction",
#     "religion": "Judaism",
#     "music": "Hip-Hop",
#     "sports": "Baseball",
#     "books": "Science Fiction",
#     "politics": "Communism"
#   },
#     {
#     "bio": "Always seeking the next great experience.",
#     "movies": "Action",
#     "religion": "Islam",
#     "music": "Classical",
#     "sports": "Basketball",
#     "books": "Fantasy",
#     "politics": "Conservatism"
#   },
#   {
#     "bio": "Living for a good laugh.",
#     "movies": "Comedy",
#     "religion": "Christianity",
#     "music": "Pop",
#     "sports": "Soccer",
#     "books": "Romance",
#     "politics": "Liberalism"
#   },
#   {
#     "bio": "Ready to find out what you're about.",
#     "movies": "

# %%
df = pd.read_csv('dating_profiles.csv')
df.head()
# Out:
#                                                 Bios           Movies  \
# 0  Avid stargazer with a penchant for philosophic...  Science Fiction
# 1  Lover of spontaneous road trips and the perfec...           Comedy
# 2  Bookworm and history buff searching for my own...            Drama
# 3  World traveler with a taste for spicy food and...           Action
# 4  Always up for a good laugh and a competitive g...           Comedy
#
#        Religion      Music      Sports            Books        Politics
# 0      Buddhism       Jazz      Tennis      Non-Fiction      Liberalism
# 1  Christianity        Pop    Baseball          Romance    Conservatism
# 2       Judaism  Classical      Soccer          Fantasy       Socialism
# 3         Islam    Hip-Hop  Basketball  Science Fiction  Libertarianism
# 4      Hinduism       Rock     Cricket          Mystery       Communism
