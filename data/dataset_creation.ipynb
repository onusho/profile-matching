# %%
import os
import time
import json
from dotenv import load_dotenv
import pandas as pd
from google import genai

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
client = genai.Client(api_key="AIzaSyArPg8FJF3YFab64UZvdgWLB_MhOZZn32Y")

# %%
# uses exponential backoff when calling gemini api
def generate_text(prompt, model="gemini-2.0-flash-lite-preview-02-05", max_retries=5, initial_wait=2):

    attempt = 0
    wait_time = initial_wait

    while attempt < max_retries:
        try:
            response = client.models.generate_content(
                model=model,
                contents=[prompt]
            )
            return response.text
        except Exception as e:
            print(f"Error encountered: {e}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
            wait_time *= 2  # backoff
            attempt += 1

    raise Exception("Max retries reached. The request could not be completed.")

def validate_profile(profile):
    required_keys = ["bio", "movies", "tv", "religion", "music", "sports", "books", "politics"]
    
    # checking all keys present or not
    for key in required_keys:
        if key not in profile:
            return False
    
    # checking range of numeric entries
    for key in ["movies", "tv", "religion", "music", "sports", "books", "politics"]:
        value = profile[key]
        if not isinstance(value, int):
            return False
        if value < 1 or value > 10:
            return False

    if not isinstance(profile["bio"], str):
        return False

    return True

def generate_profiles(n_profiles=500):
    prompt = f"""
You are a profile generator. Create {n_profiles} unique dating profiles.
Return them as a valid JSON array of objects. Each object has these fields:
    "bio": (string) a short creative biography (1-2 sentences),
    "movies": (integer 1-10),
    "tv": (integer 1-10),
    "religion": (integer 1-10),
    "music": (integer 1-10),
    "sports": (integer 1-10),
    "books": (integer 1-10),
    "politics": (integer 1-10).
Example for one item in the array:
{{
    "bio": "Coffee fanatic. Amateur traveler. Always up for a new adventure!",
    "movies": 7,
    "tv": 5,
    "religion": 2,
    "music": 9,
    "sports": 4,
    "books": 8,
    "politics": 3
}}
"""
    response_text = generate_text(prompt)
    
    try:
        # converting JSON string into list of dictionaries
        raw_profiles = json.loads(response_text)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}. Raw Response: {response_text}")
        return []
    
    valid_profiles = []
    for p in raw_profiles:
        if validate_profile(p):
            valid_profiles.append(p)

    print(f"Generated {len(valid_profiles)} valid profiles out of requested {n_profiles}.")
    return valid_profiles

if __name__ == "__main__":
    total_needed = 500
    batch_size = 250

    all_profiles = []
    total_collected = 0
 
    while total_collected < total_needed:
        needed_now = min(batch_size, total_needed - total_collected)
        batch = generate_profiles(needed_now)
        all_profiles.extend(batch)
        total_collected = len(all_profiles)
        
        time.sleep(2)
    
    df = pd.DataFrame(all_profiles)
    df.rename(
        columns={
            "bio": "Bios",
            "movies": "Movies",
            "tv": "TV",
            "religion": "Religion",
            "music": "Music",
            "sports": "Sports",
            "books": "Books",
            "politics": "Politics"
        },
        inplace=True
    )
    
    print(df.head(10))  
    print(f"\nTotal valid profiles generated: {len(df)}")
    
    df.to_csv("dating_profiles.csv", index=False)
    print("\nSaved to 'dating_profiles.csv'.")
# Out:
# Error decoding JSON: Expecting value: line 1 column 1 (char 0). Raw Response: ```json
# [
#   {
#     "bio": "Lover of vintage finds and cozy nights in. Currently binge-watching documentaries.",
#     "movies": 6,
#     "tv": 8,
#     "religion": 4,
#     "music": 7,
#     "sports": 2,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Aspiring chef with a passion for travel and a quirky sense of humor. Let's explore new places and flavors together!",
#     "movies": 9,
#     "tv": 6,
#     "religion": 7,
#     "music": 8,
#     "sports": 3,
#     "books": 5,
#     "politics": 6
#   },
#   {
#     "bio": "Tech enthusiast and outdoor adventurer. Seeking someone who appreciates both intellectual conversations and nature's beauty.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 3,
#     "music": 6,
#     "sports": 8,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Passionate about art, music, and deep conversations. Enjoying life's simple pleasures and searching for meaningful connections.",
#     "movies": 8,
#     "tv": 4,
#     "religion": 6,
#     "music": 9,
#     "sports": 1,
#     "books": 10,
#     "politics": 7
#   },
#   {
#     "bio": "Fitness fanatic with a love for cooking and trying new restaurants. Looking for a partner in crime to share life's adventures.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 2,
#     "music": 5,
#     "sports": 10,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Animal lover, travel enthusiast, and always up for a good laugh. Seeking a partner to explore the world and create lasting memories.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 5,
#     "music": 8,
#     "sports": 2,
#     "books": 6,
#     "politics": 8
#   },
#   {
#     "bio": "Bookworm who finds joy in quiet evenings and intellectual discussions. Always seeking new knowledge and experiences.",
#     "movies": 6,
#     "tv": 3,
#     "religion": 8,
#     "music": 7,
#     "sports": 4,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Adventurous spirit with a love for the outdoors and a passion for photography. Exploring the world, one snapshot at a time.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 4,
#     "music": 9,
#     "sports": 8,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Foodie and film buff looking for someone to share delicious meals and captivating movies with. Let's create our own epic story!",
#     "movies": 9,
#     "tv": 8,
#     "religion": 3,
#     "music": 6,
#     "sports": 2,
#     "books": 7,
#     "politics": 5
#   },
#   {
#     "bio": "Music enthusiast with a wide range of tastes. Searching for someone who can appreciate a good concert or a relaxing evening at home.",
#     "movies": 5,
#     "tv": 4,
#     "religion": 6,
#     "music": 10,
#     "sports": 3,
#     "books": 8,
#     "politics": 7
#   },
#   {
#     "bio": "Entrepreneurial mind with a love for innovation and solving problems. Always seeking new challenges and meaningful connections.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 2,
#     "music": 5,
#     "sports": 6,
#     "books": 9,
#     "politics": 10
#   },
#   {
#     "bio": "Traveler with a love for immersing myself in different cultures. Searching for someone with a sense of adventure and open mind.",
#     "movies": 9,
#     "tv": 5,
#     "religion": 7,
#     "music": 8,
#     "sports": 3,
#     "books": 6,
#     "politics": 4
#   },
#   {
#     "bio": "Coffee connoisseur, always looking for the perfect brew. Seeking someone who appreciates good conversations and a warm embrace.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 4,
#     "books": 8,
#     "politics": 2
#   },
#   {
#     "bio": "Gardener with a green thumb and a love for nature. Seeking someone who appreciates the beauty and tranquility of the natural world.",
#     "movies": 7,
#     "tv": 4,
#     "religion": 8,
#     "music": 9,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "History buff who loves learning about the past. Enjoying life's simple pleasures and looking for someone to share them with.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Aspiring artist with a creative spirit and a love for self-expression. Seeking someone who can appreciate my unique perspective.",
#     "movies": 8,
#     "tv": 3,
#     "religion": 6,
#     "music": 10,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Science enthusiast with a passion for exploration and discovery. Searching for someone with an inquisitive mind and a thirst for knowledge.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 8,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Yoga instructor with a love for wellness and mindful living. Seeking someone who appreciates a balanced lifestyle and inner peace.",
#     "movies": 6,
#     "tv": 8,
#     "religion": 5,
#     "music": 7,
#     "sports": 3,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Writer with a knack for storytelling and a love for words. Exploring life through my craft and seeking a creative partner.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 9,
#     "music": 8,
#     "sports": 2,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "Competitive gamer with a passion for strategy and teamwork. Ready to conquer new challenges and build strong connections.",
#     "movies": 5,
#     "tv": 9,
#     "religion": 3,
#     "music": 6,
#     "sports": 7,
#     "books": 4,
#     "politics": 2
#   },
#   {
#     "bio": "Dog lover with a furry best friend. Seeking someone who enjoys long walks in the park and cuddles on the couch.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 2,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Passionate about sustainable living and protecting our planet. Seeking someone who shares my values and environmental concerns.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 7,
#     "music": 5,
#     "sports": 6,
#     "books": 8,
#     "politics": 10
#   },
#   {
#     "bio": "Volunteer with a big heart and a desire to make a difference in the world. Searching for someone who is compassionate and caring.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 10,
#     "music": 8,
#     "sports": 3,
#     "books": 9,
#     "politics": 8
#   },
#   {
#     "bio": "Comedy enthusiast with a love for laughter and a good sense of humor. Seeking someone to share silly moments and create joyful memories.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 2,
#     "music": 6,
#     "sports": 4,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Collector of vintage vinyl and a lover of classic rock. Seeking someone who appreciates the timeless beauty of music.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 6,
#     "music": 10,
#     "sports": 2,
#     "books": 8,
#     "politics": 4
#   },
#   {
#     "bio": "Exploring the universe of flavors and always seeking the perfect meal. Seeking a partner to taste test alongside.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 3,
#     "music": 7,
#     "sports": 5,
#     "books": 4,
#     "politics": 6
#   },
#   {
#     "bio": "Passionate about self-improvement and growth. Always seeking opportunities to learn, evolve, and connect.",
#     "movies": 5,
#     "tv": 4,
#     "religion": 7,
#     "music": 6,
#     "sports": 8,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "A lover of puzzles and a fan of a good mystery. Seeking a partner to help solve life's biggest enigmas!",
#     "movies": 9,
#     "tv": 8,
#     "religion": 4,
#     "music": 5,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Adventurer with a thirst for the unknown. Constantly planning the next escapade!",
#     "movies": 7,
#     "tv": 6,
#     "religion": 6,
#     "music": 9,
#     "sports": 8,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Always on the hunt for hidden gems, from small cafes to local artists. Seeking someone who shares this passion.",
#     "movies": 8,
#     "tv": 5,
#     "religion": 3,
#     "music": 8,
#     "sports": 2,
#     "books": 7,
#     "politics": 7
#   },
#   {
#     "bio": "Dreamer who finds inspiration in the stars. Let's go stargazing!",
#     "movies": 6,
#     "tv": 7,
#     "religion": 2,
#     "music": 5,
#     "sports": 4,
#     "books": 9,
#     "politics": 2
#   },
#   {
#     "bio": "Creating good vibes and searching for similar energy! Ready to embark on new adventures.",
#     "movies": 9,
#     "tv": 9,
#     "religion": 5,
#     "music": 8,
#     "sports": 2,
#     "books": 6,
#     "politics": 8
#   },
#   {
#     "bio": "Enjoys quiet nights and deep conversations. Let's explore the world, both internal and external!",
#     "movies": 5,
#     "tv": 4,
#     "religion": 6,
#     "music": 7,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Always on a creative project, usually involves a camera or a paintbrush. Seeking someone who is equally expressive.",
#     "movies": 8,
#     "tv": 3,
#     "religion": 6,
#     "music": 10,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Big believer in the power of kindness and positivity. Always seeking to build others up.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 9,
#     "music": 6,
#     "sports": 8,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Love to laugh, and love to make others laugh. Ready for movie nights and nights on the town.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 2,
#     "music": 6,
#     "sports": 4,
#     "books": 5,
#     "politics": 3
#   },
#     {
#     "bio": "Tech geek, coffee lover, and always up for a debate. Seeking someone who's as curious as I am.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 3,
#     "music": 8,
#     "sports": 5,
#     "books": 9,
#     "politics": 7
#   },
#   {
#     "bio": "Passionate about art, music, and the pursuit of beauty. Let's explore galleries and hidden concert venues.",
#     "movies": 9,
#     "tv": 5,
#     "religion": 6,
#     "music": 10,
#     "sports": 2,
#     "books": 8,
#     "politics": 4
#   },
#   {
#     "bio": "Always up for an adventure, whether it's a hike, a road trip, or trying a new restaurant. Seeking a partner in crime.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 4,
#     "music": 7,
#     "sports": 9,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Bookworm with a love for history, fantasy, and everything in between. Let's discuss our favorite stories.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 8,
#     "music": 5,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Fitness enthusiast who enjoys running, yoga, and everything in between. Seeking a partner to stay active with.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 10,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Foodie with a passion for cooking and exploring different cuisines. Let's discover new flavors together.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Music lover who enjoys concerts, vinyl, and discovering new artists. Seeking someone to share the music with.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 4,
#     "music": 10,
#     "sports": 3,
#     "books": 5,
#     "politics": 8
#   },
#   {
#     "bio": "Entrepreneurial spirit with a drive to create and innovate. Looking for someone who shares my ambition.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 5,
#     "books": 9,
#     "politics": 10
#   },
#   {
#     "bio": "Travel enthusiast with a desire to explore the world and experience different cultures. Let's plan our next adventure.",
#     "movies": 9,
#     "tv": 5,
#     "religion": 7,
#     "music": 8,
#     "sports": 3,
#     "books": 6,
#     "politics": 4
#   },
#   {
#     "bio": "Coffee addict with a love for trying new coffee shops and brewing the perfect cup. Seeking someone who appreciates good coffee.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 4,
#     "books": 8,
#     "politics": 2
#   },
#   {
#     "bio": "Gardener with a passion for plants and creating beautiful spaces. Seeking someone who appreciates the beauty of nature.",
#     "movies": 7,
#     "tv": 4,
#     "religion": 8,
#     "music": 9,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "History buff with a fascination for the past and the stories it tells. Let's explore historical sites together.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Creative soul with a love for art, design, and expressing myself. Looking for someone who appreciates creativity.",
#     "movies": 8,
#     "tv": 3,
#     "religion": 6,
#     "music": 10,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Science enthusiast with a curiosity about the universe and the world around us. Seeking someone who loves to learn.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 8,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Yoga instructor with a passion for health, wellness, and a balanced lifestyle. Seeking someone who's mindful and caring.",
#     "movies": 6,
#     "tv": 8,
#     "religion": 5,
#     "music": 7,
#     "sports": 3,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Writer with a love for storytelling and expressing myself through words. Looking for a creative partner.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 9,
#     "music": 8,
#     "sports": 2,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "Competitive gamer with a love for strategy and teamwork. Seeking a player to level up with!",
#     "movies": 5,
#     "tv": 9,
#     "religion": 3,
#     "music": 6,
#     "sports": 7,
#     "books": 4,
#     "politics": 2
#   },
#   {
#     "bio": "Dog lover with a passion for animals and the joy they bring. Seeking someone who loves dogs as much as I do.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 2,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Committed to environmental sustainability and preserving our planet. Seeking someone who shares my values.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 7,
#     "music": 5,
#     "sports": 6,
#     "books": 8,
#     "politics": 10
#   },
#   {
#     "bio": "Dedicated to making a positive impact through volunteer work. Seeking a compassionate and kind partner.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 10,
#     "music": 8,
#     "sports": 3,
#     "books": 9,
#     "politics": 8
#   },
#   {
#     "bio": "Comedy enthusiast with a great sense of humor and a love for laughter. Let's make each other laugh!",
#     "movies": 10,
#     "tv": 9,
#     "religion": 2,
#     "music": 6,
#     "sports": 4,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Collecting and enjoying the classics, like classic rock. Let's listen to some records together!",
#     "movies": 7,
#     "tv": 5,
#     "religion": 6,
#     "music": 10,
#     "sports": 2,
#     "books": 8,
#     "politics": 4
#   },
#     {
#     "bio": "Gourmand with a discerning palate and a passion for exploring the world of food. Seeking a fellow foodie.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 3,
#     "music": 7,
#     "sports": 5,
#     "books": 4,
#     "politics": 6
#   },
#   {
#     "bio": "Believer in personal growth and always seeking to learn and evolve. Let's grow together!",
#     "movies": 5,
#     "tv": 4,
#     "religion": 7,
#     "music": 6,
#     "sports": 8,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Intrigued by mysteries and looking for someone to help solve them. Let's work together.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 4,
#     "music": 5,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Adventure is out there! Ready for new challenges and discoveries.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 6,
#     "music": 9,
#     "sports": 8,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Love to discover hidden treasures, unique cafes, and local artists. Looking for a fellow explorer.",
#     "movies": 8,
#     "tv": 5,
#     "religion": 3,
#     "music": 8,
#     "sports": 2,
#     "books": 7,
#     "politics": 7
#   },
#   {
#     "bio": "Always daydreaming and letting my mind wander. Searching for someone to share the universe with.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 2,
#     "music": 5,
#     "sports": 4,
#     "books": 9,
#     "politics": 2
#   },
#   {
#     "bio": "Aiming for good vibes and great company! Let's find our perfect match.",
#     "movies": 9,
#     "tv": 9,
#     "religion": 5,
#     "music": 8,
#     "sports": 2,
#     "books": 6,
#     "politics": 8
#   },
#   {
#     "bio": "Enjoy quiet nights and intimate conversations. Let's discover new depths together.",
#     "movies": 5,
#     "tv": 4,
#     "religion": 6,
#     "music": 7,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Always working on a creative project, usually artistic. Searching for someone to share projects and ideas.",
#     "movies": 8,
#     "tv": 3,
#     "religion": 6,
#     "music": 10,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Passionate about kindness, always seeking to lift others up. Let's create a more positive world together.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 9,
#     "music": 6,
#     "sports": 8,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Ready to laugh, share, and live life to the fullest. Seeking someone to make memories with.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 2,
#     "music": 6,
#     "sports": 4,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Passionate about data and problem-solving, constantly learning new things. Looking for someone to share ideas with.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 3,
#     "music": 8,
#     "sports": 5,
#     "books": 9,
#     "politics": 7
#   },
#   {
#     "bio": "Appreciating art, music, and the simple things. Ready for galleries and concerts.",
#     "movies": 9,
#     "tv": 5,
#     "religion": 6,
#     "music": 10,
#     "sports": 2,
#     "books": 8,
#     "politics": 4
#   },
#   {
#     "bio": "Hiking, traveling, and exploring. Looking for a partner-in-crime to explore the world.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 4,
#     "music": 7,
#     "sports": 9,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "A reader, from fantasy to history. Love to discuss stories and share ideas.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 8,
#     "music": 5,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Fitness fanatic with a focus on a healthy lifestyle. Ready to share fitness and wellness tips.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 10,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Experimenting with new recipes and exploring diverse cuisines. Looking for a food partner.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Finding and enjoying new music is my passion. Seeking someone to share musical experiences with.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 4,
#     "music": 10,
#     "sports": 3,
#     "books": 5,
#     "politics": 8
#   },
#   {
#     "bio": "Passionate entrepreneur, driving innovation. Looking for an ambitious partner with a vision.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 5,
#     "books": 9,
#     "politics": 10
#   },
#   {
#     "bio": "Traveling the world, always eager for new cultures. Let's plan a new adventure!",
#     "movies": 9,
#     "tv": 5,
#     "religion": 7,
#     "music": 8,
#     "sports": 3,
#     "books": 6,
#     "politics": 4
#   },
#   {
#     "bio": "Coffee is my elixir, seeking someone to enjoy the perfect coffee date.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 4,
#     "books": 8,
#     "politics": 2
#   },
#   {
#     "bio": "Creating beautiful spaces with my love of gardening and nature. Looking for someone to share the tranquility.",
#     "movies": 7,
#     "tv": 4,
#     "religion": 8,
#     "music": 9,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "History has always intrigued me, ready to discuss the past, one story at a time.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 3,
#     "books": 10,
#     "politics": 9
#   },
#   {
#     "bio": "Expressing myself through art, painting, and design. Looking for another creative person.",
#     "movies": 8,
#     "tv": 3,
#     "religion": 6,
#     "music": 10,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Curious about the world of science, always eager to learn. Looking for an intellectual partner.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 2,
#     "music": 6,
#     "sports": 8,
#     "books": 9,
#     "politics": 5
#   },
#   {
#     "bio": "Yoga and wellness are my passions, seeking someone to share in tranquility.",
#     "movies": 6,
#     "tv": 8,
#     "religion": 5,
#     "music": 7,
#     "sports": 3,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Writing stories and expressing myself through words. Seeking someone to write with.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 9,
#     "music": 8,
#     "sports": 2,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "Gaming and strategy are my strong suits, ready to play! Looking for a gaming partner.",
#     "movies": 5,
#     "tv": 9,
#     "religion": 3,
#     "music": 6,
#     "sports": 7,
#     "books": 4,
#     "politics": 2
#   },
#   {
#     "bio": "Love dogs and animal friends, seeking someone who loves furry friends as well.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 2,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Environment is important, I focus on sustainability. Seeking a partner who shares the passion.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 7,
#     "music": 5,
#     "sports": 6,
#     "books": 8,
#     "politics": 10
#   },
#   {
#     "bio": "Passionate about volunteering and making a difference. Looking for a kind-hearted person.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 10,
#     "music": 8,
#     "sports": 3,
#     "books": 9,
#     "politics": 8
#   },
#   {
#     "bio": "Seeking laughter and joy, always up for a laugh. Looking for someone to share laughs with.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 2,
#     "music": 6,
#     "sports": 4,
#     "books": 5,
#     "politics": 3
#   },
#     {
#     "bio": "Into tech, enjoy a good debate. Ready for an interesting discussion.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 3,
#     "music": 8,
#     "sports": 5,
#     "books": 9,
#     "politics": 7
#   },
#   {
#     "bio": "Seeking to explore the world of art and music. Ready for a concert and art gallery.",
#     "movies": 9,
#     "tv": 5,
#     "religion": 6,
#     "music": 10,
#     "sports": 2,
#     "books": 8,
#     "politics": 4
#   },
#   {
#     "bio": "Love hiking, traveling, and exploring. Looking for a partner to see the world.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 4,
#     "music": 7,
#     "sports": 9,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Enjoying reading, from fantasy to history. Seeking a book partner to share ideas with.",
#     "movies": 6,
#     "tv":
# Error decoding JSON: Expecting value: line 1 column 1 (char 0). Raw Response: ```json
# [
#   {
#     "bio": "Avid reader and aspiring chef. Looking for someone to share delicious meals and deep conversations with.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 9,
#     "politics": 4
#   },
#   {
#     "bio": "Loves hiking, good coffee, and witty banter. Seeking a partner in crime for exploring new places and ideas.",
#     "movies": 6,
#     "tv": 8,
#     "religion": 7,
#     "music": 5,
#     "sports": 3,
#     "books": 4,
#     "politics": 6
#   },
#   {
#     "bio": "Passionate about art, travel, and the environment. Let's create something beautiful together.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 2,
#     "music": 8,
#     "sports": 1,
#     "books": 7,
#     "politics": 9
#   },
#   {
#     "bio": "Tech enthusiast and gamer by night, coder and problem solver by day. Seeking someone who appreciates a good challenge.",
#     "movies": 5,
#     "tv": 9,
#     "religion": 1,
#     "music": 6,
#     "sports": 5,
#     "books": 3,
#     "politics": 5
#   },
#   {
#     "bio": "Fitness fanatic with a love for outdoor adventures. Always ready for a workout or a weekend getaway.",
#     "movies": 4,
#     "tv": 7,
#     "religion": 5,
#     "music": 3,
#     "sports": 10,
#     "books": 2,
#     "politics": 2
#   },
#   {
#     "bio": "Dreamer, artist, and lover of all things vintage. Looking for someone who can appreciate the beauty in the everyday.",
#     "movies": 10,
#     "tv": 3,
#     "religion": 4,
#     "music": 9,
#     "sports": 1,
#     "books": 6,
#     "politics": 3
#   },
#   {
#     "bio": "Enjoys philosophical discussions and intellectual debates. Seeking a partner who challenges my assumptions.",
#     "movies": 7,
#     "tv": 2,
#     "religion": 6,
#     "music": 4,
#     "sports": 2,
#     "books": 10,
#     "politics": 8
#   },
#   {
#     "bio": "Animal lover and volunteer. Looking for someone with a kind heart and a passion for making a difference.",
#     "movies": 3,
#     "tv": 5,
#     "religion": 9,
#     "music": 2,
#     "sports": 6,
#     "books": 5,
#     "politics": 7
#   },
#   {
#     "bio": "Foodie who enjoys cooking and trying new restaurants. Always up for a culinary adventure.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 3,
#     "music": 8,
#     "sports": 4,
#     "books": 3,
#     "politics": 5
#   },
#   {
#     "bio": "Music aficionado, concert-goer, and vinyl collector. Seeking someone who appreciates a good tune.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 2,
#     "music": 10,
#     "sports": 1,
#     "books": 6,
#     "politics": 2
#   },
#   {
#     "bio": "History buff and storyteller. Enjoys exploring the past and sharing interesting facts. I enjoy the quiet moments of life.",
#     "movies": 5,
#     "tv": 4,
#     "religion": 7,
#     "music": 5,
#     "sports": 3,
#     "books": 10,
#     "politics": 4
#   },
#   {
#     "bio": "Comedy lover and always up for a good laugh. Hoping to find someone with a great sense of humor.",
#     "movies": 8,
#     "tv": 9,
#     "religion": 1,
#     "music": 6,
#     "sports": 2,
#     "books": 2,
#     "politics": 3
#   },
#   {
#     "bio": "Creative writer and aspiring novelist. Looking for someone who appreciates the power of words.",
#     "movies": 6,
#     "tv": 3,
#     "religion": 5,
#     "music": 7,
#     "sports": 1,
#     "books": 9,
#     "politics": 6
#   },
#   {
#     "bio": "Board game enthusiast and puzzle solver. Seeking a strategic partner to conquer new games.",
#     "movies": 2,
#     "tv": 6,
#     "religion": 3,
#     "music": 4,
#     "sports": 7,
#     "books": 5,
#     "politics": 8
#   },
#   {
#     "bio": "Amateur astronomer and stargazer. Loves exploring the mysteries of the universe.",
#     "movies": 7,
#     "tv": 2,
#     "religion": 2,
#     "music": 5,
#     "sports": 1,
#     "books": 8,
#     "politics": 2
#   },
#   {
#     "bio": "Environmentalist and nature lover. I love long walks in the park. Seeking a sustainable partner to help protect our planet.",
#     "movies": 3,
#     "tv": 4,
#     "religion": 8,
#     "music": 6,
#     "sports": 3,
#     "books": 7,
#     "politics": 9
#   },
#   {
#     "bio": "Photography hobbyist and visual storyteller. Seeking someone to capture beautiful moments with.",
#     "movies": 8,
#     "tv": 5,
#     "religion": 4,
#     "music": 9,
#     "sports": 2,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Gardener and plant enthusiast. I want to create something beautiful with you. Looking for someone who appreciates the beauty of nature.",
#     "movies": 2,
#     "tv": 3,
#     "religion": 6,
#     "music": 3,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "World traveler and culture enthusiast. Hoping to share my experiences and learn from yours.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "DIY project enthusiast and home improver. Seeking someone who loves creating and fixing things.",
#     "movies": 4,
#     "tv": 8,
#     "religion": 1,
#     "music": 5,
#     "sports": 6,
#     "books": 2,
#     "politics": 7
#   },
#   {
#     "bio": "Science geek and curious mind. Always asking 'why?' and seeking new discoveries.",
#     "movies": 6,
#     "tv": 2,
#     "religion": 2,
#     "music": 4,
#     "sports": 3,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "Volunteer and humanitarian. I love helping others, and I'm looking for someone to join me.",
#     "movies": 3,
#     "tv": 6,
#     "religion": 10,
#     "music": 2,
#     "sports": 5,
#     "books": 8,
#     "politics": 8
#   },
#   {
#     "bio": "Social butterfly and event planner. Loves a good party and a night out on the town.",
#     "movies": 7,
#     "tv": 9,
#     "religion": 1,
#     "music": 8,
#     "sports": 4,
#     "books": 3,
#     "politics": 2
#   },
#   {
#     "bio": "Classic car enthusiast and collector. Seeking someone who appreciates the beauty of vintage vehicles.",
#     "movies": 5,
#     "tv": 3,
#     "religion": 2,
#     "music": 7,
#     "sports": 6,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "Craft beer connoisseur and brewery hopper. Seeking someone to share a pint and a good conversation.",
#     "movies": 4,
#     "tv": 5,
#     "religion": 3,
#     "music": 6,
#     "sports": 2,
#     "books": 2,
#     "politics": 7
#   },
#   {
#     "bio": "Freelance writer who enjoys traveling and meeting new people. Let's make a story together.",
#     "movies": 7,
#     "tv": 8,
#     "religion": 4,
#     "music": 9,
#     "sports": 3,
#     "books": 7,
#     "politics": 5
#   },
#   {
#     "bio": "Passionate about sustainable living and conscious consumption. Looking for an eco-conscious partner.",
#     "movies": 3,
#     "tv": 4,
#     "religion": 7,
#     "music": 6,
#     "sports": 2,
#     "books": 9,
#     "politics": 9
#   },
#   {
#     "bio": "Film student with a love for the art of cinema. Always excited to discuss movies.",
#     "movies": 10,
#     "tv": 6,
#     "religion": 2,
#     "music": 8,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Yoga instructor and wellness enthusiast. Always seeking inner peace and balance in life.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 8,
#     "music": 5,
#     "sports": 8,
#     "books": 6,
#     "politics": 3
#   },
#   {
#     "bio": "Graphic designer who loves to create and inspire. Seeking a muse and creative partner.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 3,
#     "music": 9,
#     "sports": 2,
#     "books": 4,
#     "politics": 5
#   },
#   {
#     "bio": "Professional chef and culinary artist. I want to share my passion for food and cooking.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 2,
#     "music": 7,
#     "sports": 3,
#     "books": 5,
#     "politics": 2
#   },
#   {
#     "bio": "Data scientist and problem solver. Enjoys puzzles and finding solutions.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 1,
#     "music": 3,
#     "sports": 6,
#     "books": 8,
#     "politics": 5
#   },
#   {
#     "bio": "Architect and lover of design. Seeks someone with an appreciation for beauty and structure.",
#     "movies": 8,
#     "tv": 4,
#     "religion": 3,
#     "music": 6,
#     "sports": 2,
#     "books": 7,
#     "politics": 3
#   },
#   {
#     "bio": "Software engineer and tech innovator. Seeking a partner to build the future together.",
#     "movies": 6,
#     "tv": 9,
#     "religion": 2,
#     "music": 5,
#     "sports": 3,
#     "books": 4,
#     "politics": 7
#   },
#   {
#     "bio": "Healthcare professional and empathetic caregiver. Seeking a kind-hearted and compassionate partner.",
#     "movies": 4,
#     "tv": 5,
#     "religion": 9,
#     "music": 3,
#     "sports": 6,
#     "books": 8,
#     "politics": 6
#   },
#   {
#     "bio": "Financial analyst and strategic thinker. Loves a good discussion about current events.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 3,
#     "music": 4,
#     "sports": 2,
#     "books": 7,
#     "politics": 8
#   },
#   {
#     "bio": "Musician and songwriter with a passion for creating art. Seeking someone with a love for music.",
#     "movies": 7,
#     "tv": 3,
#     "religion": 2,
#     "music": 10,
#     "sports": 1,
#     "books": 6,
#     "politics": 2
#   },
#   {
#     "bio": "Teacher and lifelong learner. Enjoys sharing knowledge and inspiring others.",
#     "movies": 3,
#     "tv": 5,
#     "religion": 7,
#     "music": 6,
#     "sports": 4,
#     "books": 9,
#     "politics": 6
#   },
#   {
#     "bio": "Accountant with a love for organization and order. Seeking a partner who appreciates routine.",
#     "movies": 4,
#     "tv": 6,
#     "religion": 1,
#     "music": 3,
#     "sports": 7,
#     "books": 5,
#     "politics": 4
#   },
#   {
#     "bio": "Real estate agent with a passion for helping people find their dream homes. Let's find yours.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 2,
#     "books": 4,
#     "politics": 5
#   },
#   {
#     "bio": "Marketing specialist and creative strategist. Seeking someone to inspire my next campaign.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 2,
#     "music": 6,
#     "sports": 1,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Project manager and organized professional. Seeking someone who appreciates planning and execution.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 4,
#     "music": 3,
#     "sports": 7,
#     "books": 3,
#     "politics": 6
#   },
#   {
#     "bio": "Writer and editor with a love for crafting stories. Seeking someone who appreciates the written word.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 2,
#     "music": 9,
#     "sports": 2,
#     "books": 10,
#     "politics": 4
#   },
#   {
#     "bio": "Entrepreneur and small business owner. Seeking someone with a drive for success.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 1,
#     "music": 8,
#     "sports": 6,
#     "books": 3,
#     "politics": 7
#   },
#   {
#     "bio": "Legal professional with a passion for justice and fairness. Seeking someone with a strong moral compass.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 6,
#     "music": 2,
#     "sports": 5,
#     "books": 9,
#     "politics": 9
#   },
#   {
#     "bio": "Researcher and academic with a love for learning and discovery. Always eager to discuss new ideas.",
#     "movies": 6,
#     "tv": 2,
#     "religion": 4,
#     "music": 5,
#     "sports": 1,
#     "books": 10,
#     "politics": 8
#   },
#   {
#     "bio": "Event coordinator and party planner. I love creating memorable experiences for others.",
#     "movies": 8,
#     "tv": 9,
#     "religion": 2,
#     "music": 7,
#     "sports": 3,
#     "books": 4,
#     "politics": 2
#   },
#   {
#     "bio": "Customer service representative with a friendly and helpful attitude. Seeking someone who values kindness.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 8,
#     "music": 4,
#     "sports": 2,
#     "books": 6,
#     "politics": 3
#   },
#   {
#     "bio": "Sales professional with a knack for connecting with people. Looking for someone fun.",
#     "movies": 7,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 6,
#     "books": 3,
#     "politics": 5
#   },
#   {
#     "bio": "Human resources specialist with a passion for helping employees. Seeking a caring partner.",
#     "movies": 3,
#     "tv": 4,
#     "religion": 7,
#     "music": 2,
#     "sports": 4,
#     "books": 8,
#     "politics": 6
#   },
#   {
#     "bio": "Administrative assistant with excellent organizational skills. Looking for someone reliable and supportive.",
#     "movies": 6,
#     "tv": 5,
#     "religion": 5,
#     "music": 3,
#     "sports": 7,
#     "books": 2,
#     "politics": 4
#   },
#     {
#     "bio": "Enthusiastic about space exploration and science fiction. Searching for my fellow star gazer.",
#     "movies": 10,
#     "tv": 8,
#     "religion": 1,
#     "music": 6,
#     "sports": 1,
#     "books": 9,
#     "politics": 2
#   },
#   {
#     "bio": "A lover of all things vintage. I enjoy thrifting, classic movies, and antique shops.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 5,
#     "politics": 5
#   },
#   {
#     "bio": "I am always learning new things and enjoy expanding my horizons. I enjoy reading and documentaries.",
#     "movies": 6,
#     "tv": 7,
#     "religion": 4,
#     "music": 5,
#     "sports": 1,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "I love spending time outdoors, hiking, camping and generally exploring. I am a nature lover.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 7,
#     "music": 6,
#     "sports": 8,
#     "books": 3,
#     "politics": 8
#   },
#   {
#     "bio": "I enjoy the simpler things in life. I am looking for someone who shares this mindset with me.",
#     "movies": 5,
#     "tv": 5,
#     "religion": 9,
#     "music": 4,
#     "sports": 3,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "A creative who expresses themselves in music. I have been playing for many years.",
#     "movies": 6,
#     "tv": 3,
#     "religion": 2,
#     "music": 10,
#     "sports": 1,
#     "books": 6,
#     "politics": 2
#   },
#   {
#     "bio": "I am a foodie with a passion for cooking. My favorite is Italian food.",
#     "movies": 7,
#     "tv": 8,
#     "religion": 3,
#     "music": 5,
#     "sports": 2,
#     "books": 4,
#     "politics": 5
#   },
#   {
#     "bio": "A lover of animals and nature. I like hiking, biking, and camping.",
#     "movies": 4,
#     "tv": 6,
#     "religion": 7,
#     "music": 4,
#     "sports": 8,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "A travel enthusiast, I love exploring new places and experiencing different cultures.",
#     "movies": 9,
#     "tv": 4,
#     "religion": 3,
#     "music": 7,
#     "sports": 2,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "I'm a fan of science fiction, video games, and staying in to watch movies. Let's binge watch.",
#     "movies": 10,
#     "tv": 9,
#     "religion": 1,
#     "music": 5,
#     "sports": 3,
#     "books": 7,
#     "politics": 2
#   },
#   {
#     "bio": "I am a homebody who enjoys relaxing and reading. I like cozy nights.",
#     "movies": 8,
#     "tv": 5,
#     "religion": 6,
#     "music": 4,
#     "sports": 1,
#     "books": 10,
#     "politics": 4
#   },
#   {
#     "bio": "I enjoy live music, concerts, and festivals. I'm always up for dancing and meeting new people.",
#     "movies": 6,
#     "tv": 3,
#     "religion": 2,
#     "music": 10,
#     "sports": 3,
#     "books": 4,
#     "politics": 3
#   },
#   {
#     "bio": "I'm a passionate sports fan. I follow the major sports and love to play sports.",
#     "movies": 4,
#     "tv": 7,
#     "religion": 4,
#     "music": 3,
#     "sports": 10,
#     "books": 2,
#     "politics": 2
#   },
#   {
#     "bio": "I am always up for a new challenge, I enjoy puzzles and board games.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 3,
#     "music": 4,
#     "sports": 7,
#     "books": 8,
#     "politics": 6
#   },
#   {
#     "bio": "I'm a self-proclaimed history buff. I enjoy reading and museums.",
#     "movies": 7,
#     "tv": 4,
#     "religion": 6,
#     "music": 5,
#     "sports": 1,
#     "books": 10,
#     "politics": 4
#   },
#   {
#     "bio": "A big fan of comedy. I enjoy stand up and comedic TV series.",
#     "movies": 9,
#     "tv": 10,
#     "religion": 1,
#     "music": 6,
#     "sports": 2,
#     "books": 3,
#     "politics": 3
#   },
#   {
#     "bio": "A lover of the arts, including music, movies, and literature. I'm always up for intellectual conversation.",
#     "movies": 10,
#     "tv": 6,
#     "religion": 2,
#     "music": 9,
#     "sports": 1,
#     "books": 9,
#     "politics": 8
#   },
#   {
#     "bio": "Looking for someone that I can build a friendship or romantic relationship with, let's chat!",
#     "movies": 7,
#     "tv": 6,
#     "religion": 4,
#     "music": 7,
#     "sports": 3,
#     "books": 5,
#     "politics": 5
#   },
#   {
#     "bio": "A fitness fanatic with a passion for health and wellness. I enjoy running and yoga.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 8,
#     "music": 5,
#     "sports": 10,
#     "books": 3,
#     "politics": 3
#   },
#   {
#     "bio": "I am always looking to learn something new. I enjoy reading and documentaries.",
#     "movies": 6,
#     "tv": 5,
#     "religion": 3,
#     "music": 4,
#     "sports": 2,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "A lover of coffee and good conversations. Let's meet up and chat over coffee.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 2,
#     "music": 6,
#     "sports": 3,
#     "books": 4,
#     "politics": 4
#   },
#   {
#     "bio": "Looking for a partner to enjoy the simple things in life.",
#     "movies": 5,
#     "tv": 4,
#     "religion": 6,
#     "music": 4,
#     "sports": 2,
#     "books": 8,
#     "politics": 5
#   },
#   {
#     "bio": "Looking for someone with a great sense of humor.",
#     "movies": 9,
#     "tv": 9,
#     "religion": 1,
#     "music": 5,
#     "sports": 3,
#     "books": 3,
#     "politics": 3
#   },
#   {
#     "bio": "An introverted artist who is looking for a life partner.",
#     "movies": 6,
#     "tv": 3,
#     "religion": 4,
#     "music": 8,
#     "sports": 1,
#     "books": 7,
#     "politics": 6
#   },
#   {
#     "bio": "Passionate about the environment, I'm looking for someone who shares my concerns about the Earth.",
#     "movies": 3,
#     "tv": 4,
#     "religion": 7,
#     "music": 6,
#     "sports": 2,
#     "books": 9,
#     "politics": 9
#   },
#   {
#     "bio": "A film student who is seeking a partner to share their passion.",
#     "movies": 10,
#     "tv": 7,
#     "religion": 2,
#     "music": 8,
#     "sports": 1,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "A yoga instructor with the goal of helping people achieve wellness.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 8,
#     "music": 5,
#     "sports": 8,
#     "books": 6,
#     "politics": 3
#   },
#   {
#     "bio": "Looking for a muse to help inspire my passion for art.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 3,
#     "music": 9,
#     "sports": 2,
#     "books": 4,
#     "politics": 5
#   },
#   {
#     "bio": "Looking for someone with a passion for cooking to cook for.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 2,
#     "music": 7,
#     "sports": 3,
#     "books": 5,
#     "politics": 2
#   },
#   {
#     "bio": "I am a data scientist who enjoys helping people solve problems.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 1,
#     "music": 3,
#     "sports": 6,
#     "books": 8,
#     "politics": 5
#   },
#   {
#     "bio": "Looking for someone who appreciates design and structure.",
#     "movies": 8,
#     "tv": 4,
#     "religion": 3,
#     "music": 6,
#     "sports": 2,
#     "books": 7,
#     "politics": 3
#   },
#   {
#     "bio": "Seeking a partner to help build a better tomorrow.",
#     "movies": 6,
#     "tv": 9,
#     "religion": 2,
#     "music": 5,
#     "sports": 3,
#     "books": 4,
#     "politics": 7
#   },
#   {
#     "bio": "Seeking a kind, compassionate partner to help people.",
#     "movies": 4,
#     "tv": 5,
#     "religion": 9,
#     "music": 3,
#     "sports": 6,
#     "books": 8,
#     "politics": 6
#   },
#   {
#     "bio": "I'm a financial analyst, and I enjoy current events.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 3,
#     "music": 4,
#     "sports": 2,
#     "books": 7,
#     "politics": 8
#   },
#   {
#     "bio": "A musician, looking for someone to help make art with.",
#     "movies": 7,
#     "tv": 3,
#     "religion": 2,
#     "music": 10,
#     "sports": 1,
#     "books": 6,
#     "politics": 2
#   },
#   {
#     "bio": "I am a teacher, and I enjoy helping people learn.",
#     "movies": 3,
#     "tv": 5,
#     "religion": 7,
#     "music": 6,
#     "sports": 4,
#     "books": 9,
#     "politics": 6
#   },
#   {
#     "bio": "A very organized accountant who loves to plan events.",
#     "movies": 4,
#     "tv": 6,
#     "religion": 1,
#     "music": 3,
#     "sports": 7,
#     "books": 5,
#     "politics": 4
#   },
#   {
#     "bio": "A real estate agent, I enjoy helping people find their dream homes.",
#     "movies": 8,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 2,
#     "books": 4,
#     "politics": 5
#   },
#   {
#     "bio": "A marketing specialist who looks for creative solutions.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 2,
#     "music": 6,
#     "sports": 1,
#     "books": 5,
#     "politics": 3
#   },
#   {
#     "bio": "Looking for a partner who enjoys planning and organization.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 4,
#     "music": 3,
#     "sports": 7,
#     "books": 3,
#     "politics": 6
#   },
#   {
#     "bio": "A writer looking for a creative life partner.",
#     "movies": 7,
#     "tv": 5,
#     "religion": 2,
#     "music": 9,
#     "sports": 2,
#     "books": 10,
#     "politics": 4
#   },
#   {
#     "bio": "An entrepreneur, looking for someone who wants to succeed.",
#     "movies": 5,
#     "tv": 7,
#     "religion": 1,
#     "music": 8,
#     "sports": 6,
#     "books": 3,
#     "politics": 7
#   },
#   {
#     "bio": "Seeking a partner who values justice.",
#     "movies": 4,
#     "tv": 3,
#     "religion": 6,
#     "music": 2,
#     "sports": 5,
#     "books": 9,
#     "politics": 9
#   },
#   {
#     "bio": "Always looking to learn and discover new things.",
#     "movies": 6,
#     "tv": 2,
#     "religion": 4,
#     "music": 5,
#     "sports": 1,
#     "books": 10,
#     "politics": 8
#   },
#   {
#     "bio": "I'm an event coordinator who loves parties.",
#     "movies": 8,
#     "tv": 9,
#     "religion": 2,
#     "music": 7,
#     "sports": 3,
#     "books": 4,
#     "politics": 2
#   },
#   {
#     "bio": "A customer service representative who is happy to help.",
#     "movies": 5,
#     "tv": 6,
#     "religion": 8,
#     "music": 4,
#     "sports": 2,
#     "books": 6,
#     "politics": 3
#   },
#   {
#     "bio": "I'm a salesman looking to make a connection.",
#     "movies": 7,
#     "tv": 7,
#     "religion": 3,
#     "music": 5,
#     "sports": 6,
#     "books": 3,
#     "politics": 5
#   },
#   {
#     "bio": "A human resources specialist with a caring attitude.",
#     "movies": 3,
#     "tv":
# Error decoding JSON: Expecting value: line 1 column 1 (char 0). Raw Response: ```json
# [
#   {
#     "bio": "Living life one sunset at a time. Passionate about photography and exploring hidden gems.",
#     "movies": 8,
#     "tv": 6,
#     "religion": 3,
#     "music": 9,
#     "sports": 2,
#     "books": 7,
#     "politics": 4
#   },
#   {
#     "bio": "Coding my way through life, fueled by pizza and good vibes. Seeking someone who appreciates a good pun.",
#     "movies": 7,
#     "tv": 8,
#     "religion": 1,
#     "music": 6,
#     "sports": 5,
#     "books": 4,
#     "politics": 7
#   },
#   {
#     "bio": "Lover of all things vintage and the sound of vinyl.  Always looking for a partner in crime for weekend road trips.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 5,
#     "music": 10,
#     "sports": 3,
#     "books": 9,
#     "politics": 2
#   },
#   {
#     "bio": "Dreamer, doer, and lover of animals.  Enjoys hiking, board games, and deep conversations.",
#     "movies": 9,
#     "tv": 7,
#     "religion": 6,
#     "music": 8,
#     "sports": 1,
#     "books": 6,
#     "politics": 5
#   },
#   {
#     "bio": "Foodie, fitness enthusiast, and world traveler.  Looking for someone to share a meal and explore the world with.",
#     "movies": 7,
#     "tv": 6,
#     "religion": 2,
#     "music": 5,
#     "sports": 8,
#     "books": 3,
#     "politics": 9
#   },
#   {
#     "bio": "Bookworm and aspiring writer.  Prefers rainy days, cozy blankets, and good stories.",
#     "movies": 5,
#     "tv": 3,
#     "religion": 8,
#     "music": 7,
#     "sports": 1,
#     "books": 10,
#     "politics": 6
#   },
#   {
#     "bio": "Tech geek and gamer at heart.  Always up for a late night gaming session.",
#     "movies": 8,
#     "tv": 9,
#     "religion": 1,
#     "music": 4,
#     "sports": 2,
#     "books": 3,
#     "politics": 7
#   },
#   {
#     "bio": "Artist, art history buff, and lover of museums.  Searching for a fellow creative soul.",
#     "movies": 6,
#     "tv": 5,
#     "religion": 4,
#     "music": 9,
#     "sports": 1,
#     "books": 8,
#     "politics": 3
#   },
#   {
#     "bio": "Outdoor adventurer and nature lover.  Always ready for a hike, bike ride, or camping trip.",
#     "movies": 4,
#     "tv": 2,
#     "religion": 3,
#     "music": 6,
#     "sports": 10,
#     "books": 5,
#     "politics": 8
#   },
#     {
#     "bio": "Passionate about sustainability and living green.  Hoping to find someone who shares similar values.",
#     "movies": 7,
#     "tv": 8,
#     "religion": 7,
#     "music": 5,
#     "sports": 2,
#     "books": 9,
#     "politics": 10
#   },
#   {
#     "bio": "Craft beer aficionado and concert goer.  Seeking someone to share a pint and enjoy some live music.",
#     "movies": 6,
#     "tv": 4,
#     "religion": 2,
#     "music": 10,
#     "sports": 3,
#     "books": 4,
#     "politics": 1
#   },
#   {
#     "bio": "Yoga instructor, wellness advocate, and mindfulness practitioner.  Seeking a peaceful and balanced relationship.",
#     "movies": 5,
#     "tv": 3,
#     "religion": 9,
#     "music": 8,
#     "sports": 6,
#     "books": 7,
#     "politics": 5
#   },
#   {
#     "bio": "Comedy enthusiast and stand-up fanatic.  Looking for someone who can make me laugh.",
#     "movies": 9,
#     "tv": 8,
#     "religion": 1,
#     "music": 5,
#     "sports": 2,
#     "books": 2,
# ...
#         "movies": 3,
#         "tv": 3,
#         "religion": 3,
#         "music": 6,
#         "sports": 9,
#         "books": 5,
#         "politics": 6
#     },
#     {
#         "bio": "I am a huge movie buff who loves all genres of film.  I'm hoping to find someone who is just as passionate about movies as I am.",
#         "movies": 10,
#         "tv": 6,
#         "religion": 1,
#         "music": 5,
#         "sports": 2,
#         "books": 3,
#         "politics": 1
#     },
#     {
#         "bio": "I love to read and have a good conversation about books. Looking for a partner to share that interest.",
#         "movies": 4,
#         "tv": 2,
#         "religion": 5,
#         "music": 3,
#         "sports": 1,
#         "books": 10,
#         "politics": 3
#     },
#     {
#         "bio": "I have a strong sense of humor and love to make people laugh.  I love comedies!",
#         "movies": 9,
#         "tv": 8,
#         "religion": 2,
#         "music": 7,
#         "sports": 4,
#         "books": 2,
#         "politics": 2
#     },
#     {
#         "bio": "I'm passionate about politics and social justice, I am seeking a like-minded individual.",
#         "movies": 5,
#         "tv": 4,
#         "religion": 8,
#         "music": 6,
#         "sports": 3,
#         "books": 9,
#         "politics": 10
#     },
#     {
#         "bio": "I love art and music.  I love concerts and spending my free time creating.",
#         "movies": 9,
#         "tv": 5,
#         "religion": 3,
#         "music": 10,
#         "sports": 2,
#         "books": 6,
#         "politics": 4
#     },
#     {
#         "bio": "I'm an avid athlete and am always up for a new challenge.  Seeking someone to join me.",
#         "movies": 4,
#         "tv": 6,
#         "religion": 2,
#         "music": 5,
#         "sports": 10,
#         "books": 3,
#         "politics": 6
#     },
#     {
#         "bio": "I enjoy a quiet life, a good book, and the simple pleasures. Ready to find a companion who appreciates those moments.",
#         "movies": 7,
#         "tv": 3,
#         "religion": 4,
#         "music": 5,
#         "sports": 1,
#         "books": 10,
#         "politics": 2
#     },
#     {
#         "bio": "I'm a travel enthusiast with a long bucket list.  Seeking someone to explore the world with.",
#         "movies": 9,
#         "tv": 6,
#         "religion": 9,
#         "music": 6,
#         "sports": 4,
#         "books": 7,
#         "politics": 8
#     },
#     {
#         "bio": "I am a coffee enthusiast and enjoy going to cafes. I'm seeking someone to go with me!",
#         "movies": 5,
#         "tv": 5,
#         "religion": 4,
#         "music": 4,
#         "sports": 2,
#         "books": 7,
#         "politics": 4
#     },
#     {
#         "bio": "I have a deep love for animals and volunteering at the local animal shelter is my passion.  Looking for someone who shares my affection.",
#         "movies": 3,
#         "tv": 7,
#         "religion": 3,
#         "music": 5,
#         "sports": 2,
#         "books": 3,
#         "politics": 5
#     },
#     {
#         "bio": "I enjoy a good meal and trying out new restaurants.  I'm looking for a partner in crime for my foodie adventures!",
#         "movies": 8,
#         "tv": 6,
#         "religion": 1,
#         "music": 6,
#         "sports": 1,
#         "books": 4,
#         "politics": 1
#     },
#     {
#         "bio": "I like to learn new things and read, and hope to find someone else who enjoys that as well.",
#         "movies": 5,
#         "tv": 4,
#         "religion": 8,
#         "music": 7,
#         "sports": 8,
#         "books": 9,
#         "politics": 9
#     },
#     {
#         "bio": "I love to go to local music concerts, play board games, or just take a walk in the park. Looking for someone to join me!",
#         "movies": 8,
#         "tv": 4,
#         "religion": 2,
#         "music": 9,
#         "sports": 1,
#         "books": 5,
#         "politics": 3
#     },
#     {
#         "bio": "I like to go to the theater, or spend time at a museum. Ready to find someone who also enjoys those things.",
#         "movies": 9,
#         "tv": 5,
#         "religion": 6,
#         "music": 8,
#         "sports": 3,
#         "books": 7,
#         "politics": 7
#     },
#     {
#         "bio": "I appreciate the simple things, from the sun to coffee, and I am looking for someone who enjoys them as well.",
#         "movies": 5,
#         "tv": 3,
#         "religion": 4,
#         "music": 6,
#         "sports": 7,
#         "books": 2,
#         "politics": 5
#     },
#     {
#         "bio": "I love to travel and see new places.  I'm looking for someone who is also interested in travel.",
#         "movies": 7,
#         "tv": 6,
#         "religion": 9,
#         "music": 5,
#         "sports": 2,
#         "books": 8,
#         "politics": 8
#     },
#     {
#         "bio": "I love good conversation, kindness, and honesty. Ready to find someone to share that with.",
#         "movies": 6,
#         "tv": 9,
#         "religion": 3,
#         "music": 7,
#         "sports": 8,
#         "books": 3,
#         "politics": 1
#     },
#     {
#         "bio": "I like to help others and have compassion, and I hope to find someone else who enjoys these things.",
#         "movies": 4,
#         "tv": 5,
#         "religion": 7,
#         "music": 4,
#         "sports": 2,
#         "books": 9,
#         "politics": 6
#     },
#     {
#         "bio": "I enjoy history and learning about different cultures. I'm looking for someone to explore those with.",
#         "movies": 8,
#         "tv": 7,
#         "religion": 8,
#         "music": 6,
#         "sports": 4,
#         "books": 10,
#         "politics": 5
#     },
#     {
#         "bio": "I'm always up for trying something new and enjoy good food. Looking for someone who likes those things too.",
#         "movies": 9,
#         "tv": 9,
#         "religion": 1,
#         "music": 8,
#         "sports": 1,
#         "books": 2,
#         "politics": 2
#     },
#     {
#         "bio": "I enjoy being outdoors, seeing nature, and spending time in the fresh air. Seeking a like-minded person.",
#         "movies": 3,
#         "tv": 2,
#         "religion": 2,
#         "music": 4,
#         "sports": 10,
#         "books": 6,
#         "politics": 3
#     },
#     {
#         "bio": "I enjoy listening to indie music and going to concerts.  I hope to find someone to share those things with.",
#         "movies": 7,
#         "tv": 5,
#         "religion": 3,
#         "music": 10,
#         "sports": 5,
#         "books": 4,
#         "politics": 8
#     },
#     {
#         "bio": "I love being at home and relaxing with a good book or movie. I'm looking for someone to spend those times with.",
#         "movies": 10,
#         "tv": 8,
#         "religion": 1,
#         "music": 4,
#         "sports": 1,
#         "books": 9,
#         "politics": 2
#     },
#     {
#         "bio": "I love learning and am always trying to grow. Looking for a partner who is also curious and likes learning.",
#         "movies": 5,
#         "tv": 6,
#         "religion": 5,
#         "music": 6,
#         "sports": 7,
#         "books": 9,
#         "politics": 6
#     },
#     {
#         "bio": "I enjoy the nightlife and going out.  Seeking someone to go out with and enjoy.",
#         "movies": 8,
#         "tv": 7,
#         "religion": 2,
#         "music": 9,
#         "sports": 3,
#         "books": 3,
#         "politics": 9
#     },
#     {
#         "bio": "I love to help others and believe in giving back to the community. I'm looking for someone who believes the same.",
#         "movies": 4,
#         "tv": 3,
#         "religion": 9,
#         "music": 4,
#         "sports": 2,
#         "books": 7,
#         "politics": 10
#     },
#     {
#         "bio": "I love a challenge and solving problems. I'm looking for someone who is also up for challenges.",
#         "movies": 6,
#         "tv": 4,
#         "religion": 6,
#         "music": 6,
#         "sports": 6,
#         "books": 8,
#         "politics": 4
#     },
#     {
#         "bio": "I'm always up for a good night out with friends, dancing, and laughing. Looking to add to the fun!",
#         "movies": 9,
#         "tv": 8,
#         "religion": 1,
#         "music": 10,
#         "sports": 3,
#         "books": 2,
#         "politics": 1
#     },
#     {
#         "bio": "I'm always up for trying new places, experiences, and foods. Looking for someone to share this with.",
#         "movies": 8,
#         "tv": 7,
#         "religion": 2,
#         "music": 7,
#         "sports": 5,
#         "books": 4,
#         "politics": 3
#     },
#     {
#         "bio": "I love the outdoors and the activities that it involves. I'm seeking someone who also enjoys nature.",
#         "movies": 3,
#         "tv": 3,
#         "religion": 3,
#         "music": 6,
#         "sports": 9,
#         "books": 5,
#         "politics": 6
#     },
#     {
#         "bio": "I love movies of all genres and spending time watching them.  I hope to find someone with the same love for movies!",
#         "movies": 10,
#         "tv": 6,
#         "religion": 1,
#         "music": 5,
#         "sports": 2,
#         "books": 3,
#         "politics": 1
#     },
#     {
#         "bio": "I enjoy reading and sharing books with others. I'm looking for a partner to read and discuss with.",
#         "movies": 4,
#         "tv": 2,
#         "religion": 5,
#         "music": 3,
#         "sports": 1,
#         "books": 10,
#         "politics": 3
#     },
#     {
#         "bio": "I love a good joke and making people laugh, hoping to find someone with the same love for comedy!",
#         "movies": 9,
#         "tv": 8,
#         "religion": 2,
#         "music": 7,
#         "sports": 4,
#         "books": 2,
#         "politics": 2
#     },
#     {
#         "bio": "I'm passionate about politics and seeking a partner who shares this passion for social justice.",
#         "movies": 5,
#         "tv": 4,
#         "religion": 8,
#         "music": 6,
#         "sports": 3,
#         "books": 9,
#         "politics": 10
#     },
#     {
#         "bio": "I enjoy art and music and hope to find someone to create with and explore with!",
#         "movies": 9,
#         "tv": 5,
#         "religion": 3,
#         "music": 10,
#         "sports": 2,
#         "books": 6,
#         "politics": 4
#     },
#     {
#         "bio": "I'm an avid athlete and love to play sports and am seeking a partner who enjoys it as well!",
#         "movies": 4,
#         "tv": 6,
#         "religion": 2,
#         "music": 5,
#         "sports": 10,
#         "books": 3,
#         "politics": 6
#     },
#     {
#         "bio": "I enjoy the quiet life, a good book, and the simple pleasures.  I'm seeking someone who appreciates that, too.",
#         "movies": 7,
#         "tv": 3,
#         "religion": 4,
#         "music": 5,
#         "sports": 1,
#         "books": 10,
#         "politics": 2
#     },
#     {
#         "bio": "I love to travel the world and always have a trip planned! Looking for someone to explore with.",
#         "movies": 9,
#         "tv": 6,
#         "religion": 9,
#         "music": 6,
#         "sports": 4,
#         "books": 7,
#         "politics": 8
#     },
#     {
#         "bio": "Coffee is my favorite drink, and I'm looking for someone who enjoys going to cafes and spending time there.",
#         "movies": 5,
#         "tv": 5,
#         "religion": 4,
#         "music": 4,
#         "sports": 2,
#         "books": 7,
#         "politics": 4
#     },
#     {
#         "bio": "I love animals and volunteering with them is my passion. I hope to find someone who shares this.",
#         "movies": 3,
#         "tv": 7,
#         "religion": 3,
#         "music": 5,
#         "sports": 2,
#         "books": 3,
#         "politics": 5
#     },
#     {
#         "bio": "I love good food and am always exploring new restaurants. I'm hoping to find a partner to enjoy this with.",
#         "movies": 8,
#         "tv": 6,
#         "religion": 1,
#         "music": 6,
#         "sports": 1,
#         "books": 4,
#         "politics": 1
#     },
#     {
#         "bio": "I'm always learning and growing. I hope to find someone who appreciates this and also enjoys learning.",
#         "movies": 5,
#         "tv": 4,
#         "religion": 8,
#         "music": 7,
#         "sports": 8,
#         "books": 9,
#         "politics": 9
#     },
#     {
#         "bio": "I like concerts, board games, and walking in the park. I'm looking for someone to join me!",
#         "movies": 8,
#         "tv": 4,
#         "religion": 2,
#         "music": 9,
#         "sports": 1,
#         "books": 5,
#         "politics": 3
#     },
#     {
#         "bio": "I enjoy theater and museums and am hoping to find someone with the same interests to explore them with.",
#         "movies": 9,
#         "tv": 5,
#         "religion": 6,
#         "music": 8,
#         "sports": 3,
#         "books": 7,
#         "politics": 7
#     },
#     {
#         "bio": "I enjoy the simple things in life, like sunshine and coffee, and am seeking someone who enjoys the same.",
#         "movies": 5,
#         "tv": 3,
#         "religion": 4,
#         "music": 6,
#         "sports": 7,
#         "books": 2,
#         "politics": 5
#     },
#     {
#         "bio": "I love to travel and always have a trip planned.  Seeking someone to explore the world with.",
#         "movies": 7,
#         "tv": 6,
#         "religion": 9,
#         "music": 5,
#         "sports": 2,
#         "books": 8,
#         "politics": 8
#     },
#     {
#         "bio": "I value kindness, honesty, and good conversation. Seeking someone who appreciates these things, too.",
#         "movies": 6,
#         "tv": 9,
#         "religion": 3,
#         "music": 7,
#         "sports": 8,
#         "books": 3,
#         "politics": 1
#     },
#     {
#         "bio": "I like to help others and have compassion. I hope to find someone with the same qualities.",
#         "movies": 4,
#         "tv": 5,
#         "religion": 7,
#         "music": 4,
#         "sports": 2,
#         "books": 9,
#         "politics": 6
#     },
#     {
#         "bio": "I enjoy learning about history and other cultures.  I hope to find someone to learn with.",
#         "movies": 8,
#         "tv": 7,
#         "religion": 8,
#         "music": 6,
#         "sports": 4,
#         "books": 10,
#         "politics": 5
#     },
#     {
#         "bio": "I love trying new foods and new adventures! Looking for someone with the same love.",
#         "movies": 9,
#         "tv": 9,
#         "religion": 1,
#         "music": 8,
#         "sports": 1,
#         "books": 2,
#         "politics": 2
#     },
#     {
#         "bio": "I love to spend time outdoors and enjoying nature. I'm hoping to find someone who enjoys the same.",
#         "movies": 3,
#         "tv": 2,
#         "religion": 2,
#         "music": 4,
#         "sports": 10,
#         "books": 6,
#         "politics": 3
#     },
#     {
#         "bio": "I love indie music and going to concerts. I hope to find someone to share that with!",
#         "movies": 7,
#         "tv": 5,
#         "religion": 3,
#         "music": 10,
#         "sports": 5,
#         "books": 4,
#         "politics": 8
#     },
#     {
#         "bio": "I love the peace of being at home, watching movies, and reading. Hoping to find someone to enjoy this with.",
#         "movies": 10,
#         "tv": 8,
#         "religion": 1,
#         "music": 4,
#         "sports": 1,
#         "books": 9,
#         "politics": 2
#     },
#     {
#         "bio": "I love to learn and grow, hoping to find someone who loves that as well.",
#         "movies": 5,
#         "tv": 6,
#         "religion": 5,
#         "music": 6,
#         "sports": 7,
#         "books": 9,
#         "politics": 6
#     },
#     {
#         "bio": "I'm a night owl and love going out and seeing the city. Seeking someone to enjoy this with!",
#         "movies": 8,
#         "tv": 7,
#         "religion": 2,
#         "music": 9,
#         "sports": 3,
#         "books": 3,
#         "politics": 9
#     },
#     {
#         "bio": "I love to help and give back to the community. Hoping to find someone with this compassion as well.",
#         "movies": 4,
#         "tv": 3,
#         "religion": 9,
#         "music": 4,
#         "sports": 2,
#         "books": 7,
#         "politics": 10
#     },
#     {
#         "bio": "I love a good challenge and solving problems. I am hoping to find someone who enjoys the same!",
#         "movies": 6,
#         "tv": 4,
#         "religion": 6,
#         "music": 6,
#         "sports": 6,
#         "books": 8,
#         "politics": 4
#     },
#     {
#         "bio": "I enjoy dancing, music, and friends. I'm hoping to find someone who will add to the fun
